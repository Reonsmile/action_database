# %%
# !mkdir action
# %cd ./action
# %pwd
# Out:
# /Users/reon/Documents/matlabs/actions_database/action
# '/Users/reon/Documents/matlabs/actions_database/action'

# %%
import pandas as pd

# Load the CSV file
file_path = '../actions_database.csv'
data = pd.read_csv(file_path)

# %%
# Select the required columns and convert to a list of lists
actions_list = data[['モノ', '行為']].values.tolist()
print(actions_list)
# Out:
# [['本', '本を手に取る'], ['本', '表紙を開く'], ['本', 'ページをめくる'], ['本', 'しおりを挟む'], ['本', '読むための姿勢をとる'], ['本', 'ライトを点ける'], ['本', '眼鏡をかける'], ['本', 'ページの角を折る'], ['本', '読み進める'], ['本', '段落を飛ばす'], ['本', '辞書を引く'], ['本', '読み終わったページを閉じる'], ['本', '本棚に戻す'], ['本', '別の本を選ぶ'], ['本', '付箋を貼る'], ['本', 'メモを取る'], ['本', 'アンダーラインを引く'], ['本', '再度読み返す'], ['本', '挿絵を見る'], ['本', '表紙を閉じる'], ['本', '読書灯で照らす'], ['本', '眼鏡をかける'], ['本', 'コーヒーを飲む'], ['本', '音楽を聴く'], ['本', 'ブランケットをかける'], ['本', '椅子に座る'], ['本', 'ソファでくつろぐ'], ['本', 'メモ帳にメモを取る'], ['本', 'ペンを使って線を引く'], ['本', 'スマホで調べ物をする'], ['本', 'タブレットで関連情報を読む'], ['本', '時計を確認する'], ['本', 'スナックを食べる'], ['本', '本立てに立てかける'], ['本', 'ブックカバーをかける'], ['本', '本棚に収納する'], ['本', 'しおりを挟む'], ['本', '枕を使って寝転がる'], ['本', 'ブックライトを使う'], ['本', 'カーテンを閉める'], ['本', '本を積み上げてタワーを作る'], ['本', '本でドミノをする'], ['本', '本のページで折り紙をする'], ['本', '本の中にメッセージを隠す'], ['本', '本を開いて隠れる'], ['本', '本を使って積み木をする'], ['本', '本のページに絵を描く'], ['本', '本を使って仮面を作る'], ['本', '本を並べて道を作る'], ['本', '本を使って家を作る'], ['本', '本を飛ばしてキャッチする'], ['本', '本でバランスゲームをする'], ['本', '本の中に小物を隠す'], ['本', '本を投げて距離を競う'], ['本', '本を積み上げて競う'], ['本', '本でトンネルを作る'], ['本', '本の中に手紙を隠す'], ['本', '本を重ねて高さを競う'], ['本', '本のページを使って迷路を作る'], ['本', '本で風を送る'], ['本', 'ページをめくる'], ['本', '指をなめる'], ['本', '本を持ち上げる'], ['本', '本を傾ける'], ['本', 'ページの角を折る'], ['本', '本を閉じる'], ['本', '読む速度を変える'], ['本', '目をこする'], ['本', '読んでいる場所を見失う'], ['本', 'しおりを挟む'], ['本', '本を机に置く'], ['本', '本を膝の上に置く'], ['本', '本を開いたまま置く'], ['本', 'ページを撫でる'], ['本', '本を上下逆にする'], ['本', '本を片手で持つ'], ['本', '頭をかく'], ['本', '本の匂いを嗅ぐ'], ['本', '本を指で叩く'], ['本', '本を手元に引き寄せる'], ['本', '本を落とす'], ['本', 'ページを破る'], ['本', 'しおりをなくす'], ['本', '本を濡らす'], ['本', '本を汚す'], ['本', 'ページを折る'], ['本', 'ページが引っかかる'], ['本', '本を破る'], ['本', '誤って本を閉じる'], ['本', 'ページを抜かす'], ['本', '本が開かない'], ['本', '指を切る'], ['本', '本を忘れる'], ['本', '誤って線を引く'], ['本', '付箋をなくす'], ['本', '本を踏む'], ['本', '本を逆さまに読む'], ['本', '本を紛失する'], ['本', '本のカバーを破る'], ['本', '本が見つからない'], ['本', '本を貸す'], ['本', '本を借りる'], ['本', '本を共有する'], ['本', '本について話す'], ['本', '本を推薦する'], ['本', '本を贈る'], ['本', '本を返す'], ['本', '一緒に読む'], ['本', '読書会をする'], ['本', '感想を交換する'], ['本', '本を見せる'], ['本', '本を取り合う'], ['本', '本について議論する'], ['本', '本を読む時間を作る'], ['本', '本をプレゼントする'], ['本', '本を交換する'], ['本', '本を置き忘れる'], ['本', '本を探し合う'], ['本', '本を手渡す'], ['本', '本を分け合う'], ['電子書籍', 'デバイスを手に取る'], ['電子書籍', '電源を入れる'], ['電子書籍', 'アプリを開く'], ['電子書籍', '電子書籍を選ぶ'], ['電子書籍', 'ページをスワイプする'], ['電子書籍', 'しおりを挿入する'], ['電子書籍', '読むための姿勢をとる'], ['電子書籍', '画面の明るさを調整する'], ['電子書籍', 'フォントサイズを変更する'], ['電子書籍', '辞書機能を使う'], ['電子書籍', 'メモを追加する'], ['電子書籍', 'ハイライトを引く'], ['電子書籍', 'ページをブックマークする'], ['電子書籍', '再度開く'], ['電子書籍', 'ノートを取る'], ['電子書籍', '画面をスクロールする'], ['電子書籍', '一時停止する'], ['電子書籍', '他のアプリを開く'], ['電子書籍', 'デバイスを充電する'], ['電子書籍', 'デバイスをシャットダウンする'], ['電子書籍', '読書灯で照らす'], ['電子書籍', '眼鏡をかける'], ['電子書籍', 'コーヒーを飲む'], ['電子書籍', '音楽を聴く'], ['電子書籍', 'ブランケットをかける'], ['電子書籍', '椅子に座る'], ['電子書籍', 'ソファでくつろぐ'], ['電子書籍', 'メモ帳にメモを取る'], ['電子書籍', 'ペンを使ってノートを取る'], ['電子書籍', 'スマホで調べ物をする'], ['電子書籍', 'タブレットで関連情報を読む'], ['電子書籍', '時計を確認する'], ['電子書籍', 'スナックを食べる'], ['電子書籍', 'デバイスカバーをかける'], ['電子書籍', 'デバイススタンドを使用する'], ['電子書籍', 'しおりを挿入する'], ['電子書籍', '枕を使って寝転がる'], ['電子書籍', 'ブックライトを使う'], ['電子書籍', 'カーテンを閉める'], ['電子書籍', 'イヤホンを使う'], ['電子書籍', 'デバイスを積み上げてタワーを作る'], ['電子書籍', 'デバイスでドミノをする'], ['電子書籍', 'スクリーンショットを撮る'], ['電子書籍', 'デバイスを隠す'], ['電子書籍', 'デバイスを開いて隠れる'], ['電子書籍', 'デバイスで積み木をする'], ['電子書籍', '画面に絵を描く'], ['電子書籍', 'デバイスを使って仮面を作る'], ['電子書籍', 'デバイスを並べて道を作る'], ['電子書籍', 'デバイスで家を作る'], ['電子書籍', 'デバイスを飛ばしてキャッチする'], ['電子書籍', 'デバイスでバランスゲームをする'], ['電子書籍', 'デバイスに小物を隠す'], ['電子書籍', 'デバイスを投げて距離を競う'], ['電子書籍', 'デバイスを積み上げて競う'], ['電子書籍', 'デバイスでトンネルを作る'], ['電子書籍', 'デバイスに手紙を隠す'], ['電子書籍', 'デバイスを重ねて高さを競う'], ['電子書籍', 'デバイスで迷路を作る'], ['電子書籍', 'デバイスで風を送る'], ['電子書籍', 'ページをスワイプする'], ['電子書籍', '画面をタップする'], ['電子書籍', 'デバイスを持ち上げる'], ['電子書籍', 'デバイスを傾ける'], ['電子書籍', 'ページを閉じる'], ['電子書籍', '読む速度を変える'], ['電子書籍', '目をこする'], ['電子書籍', '読んでいる場所を見失う'], ['電子書籍', 'しおりを挿入する'], ['電子書籍', 'デバイスを机に置く'], ['電子書籍', 'デバイスを膝の上に置く'], ['電子書籍', 'デバイスを開いたまま置く'], ['電子書籍', '画面を撫でる'], ['電子書籍', 'デバイスを上下逆にする'], ['電子書籍', 'デバイスを片手で持つ'], ['電子書籍', '頭をかく'], ['電子書籍', '画面の匂いを嗅ぐ'], ['電子 ...

# %%
import spacy
from spacy import displacy
from spacy.tokens import Token

# Load the Japanese language model
nlp = spacy.load('ja_ginza')

# Register custom extensions
Token.set_extension('compound_text', default=None)
Token.set_extension('mark_text', default=None)
Token.set_extension('nmod_text', default=None)
Token.set_extension('aux_text', default=None)
Token.set_extension('advcl_text', default=None)

# Function to process the sentence and combine tokens based on the given rules
def process_sentence(doc):
    for token in doc:
        if token.dep_ == 'compound':
            token.head._.compound_text = token.text + token.head.text
        elif token.dep_ == 'mark':
            token.head._.mark_text = token.text + token.head.lemma_
        elif token.dep_ == 'nmod':
            token.head._.nmod_text = token.head.text + token.text
        elif token.dep_ == 'aux':
            token.head._.aux_text = token.head.lemma_ + token.text
        elif token.dep_ == 'advcl':
            token.head._.advcl_text = token.head.lemma_ + token.text

# Function to perform dependency parsing and convert results to RDF format
def analyze_dependency(actions):
    results = []
    for action in actions:
        item, act = action
        doc = nlp(act)
        process_sentence(doc)

        dependencies = [(token.text, token.lemma_, token.pos_, token.dep_, token.head.text) for token in doc]
        rdf_triples = []
        
        # obj, obl relationships
        for token in doc:
            head_text = token.head.lemma_
            if token.head._.mark_text:
                head_text = token.head._.mark_text
            if token.head._.aux_text:
                head_text = token.head._.aux_text
            if token.dep_ in ('obj', 'obl') and token.head.pos_ == 'VERB':
                rdf_triples.append((token.text, head_text, '行為'))
        
        # NOUN relationships
        nouns = [token.text for token in doc if token.pos_ == 'NOUN']
        if len(nouns) == 2:
            rdf_triples.append((nouns[0], nouns[1], '使用'))
        elif len(nouns) > 2:
            for i in range(len(nouns)):
                for j in range(i + 1, len(nouns)):
                    rdf_triples.append((nouns[i], nouns[j], '使用'))
        
        results.append((item, act, rdf_triples))
    return results

# %%
# Analyze dependencies
dependencies_list = analyze_dependency(actions_list)

# Print the results
for item, act, rdf_triples in dependencies_list:
    print(f"Item: {item}, Action: {act}")
    for rdf in rdf_triples:
        print(f"  RDF: ({rdf[0]}, {rdf[1]}, {rdf[2]})")
# Out:
# Item: 本, Action: 本を手に取る
#   RDF: (本, 取る, 行為)
#   RDF: (手, 取る, 行為)
#   RDF: (本, 手, 使用)
# Item: 本, Action: 表紙を開く
#   RDF: (表紙, 開く, 行為)
# Item: 本, Action: ページをめくる
# Item: 本, Action: しおりを挟む
#   RDF: (しおり, 挟む, 行為)
# Item: 本, Action: 読むための姿勢をとる
#   RDF: (姿勢, とる, 行為)
#   RDF: (ため, 姿勢, 使用)
# Item: 本, Action: ライトを点ける
#   RDF: (ライト, 点ける, 行為)
# Item: 本, Action: 眼鏡をかける
#   RDF: (眼鏡, かける, 行為)
# Item: 本, Action: ページの角を折る
#   RDF: (角, 折る, 行為)
#   RDF: (ページ, 角, 使用)
# Item: 本, Action: 読み進める
# Item: 本, Action: 段落を飛ばす
#   RDF: (段落, 飛ばす, 行為)
# Item: 本, Action: 辞書を引く
#   RDF: (辞書, 引く, 行為)
# Item: 本, Action: 読み終わったページを閉じる
#   RDF: (ページ, 閉じる, 行為)
# Item: 本, Action: 本棚に戻す
#   RDF: (本棚, 戻す, 行為)
# Item: 本, Action: 別の本を選ぶ
#   RDF: (本, 選ぶ, 行為)
# Item: 本, Action: 付箋を貼る
#   RDF: (付箋, 貼る, 行為)
# Item: 本, Action: メモを取る
#   RDF: (メモ, 取る, 行為)
# Item: 本, Action: アンダーラインを引く
#   RDF: (アンダーライン, 引く, 行為)
# Item: 本, Action: 再度読み返す
# Item: 本, Action: 挿絵を見る
#   RDF: (挿絵, 見る, 行為)
# Item: 本, Action: 表紙を閉じる
#   RDF: (表紙, 閉じる, 行為)
# Item: 本, Action: 読書灯で照らす
#   RDF: (灯, 照らす, 行為)
#   RDF: (読書, 灯, 使用)
# Item: 本, Action: 眼鏡をかける
#   RDF: (眼鏡, かける, 行為)
# Item: 本, Action: コーヒーを飲む
#   RDF: (コーヒー, 飲む, 行為)
# Item: 本, Action: 音楽を聴く
#   RDF: (音楽, 聴く, 行為)
# Item: 本, Action: ブランケットをかける
#   RDF: (ブランケット, かける, 行為)
# Item: 本, Action: 椅子に座る
#   RDF: (椅子, 座る, 行為)
# Item: 本, Action: ソファでくつろぐ
#   RDF: (ソファ, くつろぐ, 行為)
# Item: 本, Action: メモ帳にメモを取る
#   RDF: (メモ帳, 取る, 行為)
#   RDF: (メモ, 取る, 行為)
#   RDF: (メモ帳, メモ, 使用)
# Item: 本, Action: ペンを使って線を引く
#   RDF: (ペン, て使う, 行為)
#   RDF: (線, 引く, 行為)
#   RDF: (ペン, 線, 使用)
# Item: 本, Action: スマホで調べ物をする
#   RDF: (スマホ, する, 行為)
#   RDF: (調べ物, する, 行為)
#   RDF: (スマホ, 調べ物, 使用)
# Item: 本, Action: タブレットで関連情報を読む
#   RDF: (タブレット, 読む, 行為)
#   RDF: (情報, 読む, 行為)
#   RDF: (タブレット, 関連, 使用)
#   RDF: (タブレット, 情報, 使用)
#   RDF: (関連, 情報, 使用)
# Item: 本, Action: 時計を確認する
#   RDF: (時計, 確認する, 行為)
# Item: 本, Action: スナックを食べる
#   RDF: (スナック, 食べる, 行為)
# Item: 本, Action: 本立てに立てかける
# Item: 本, Action: ブックカバーをかける
#   RDF: (ブックカバー, かける, 行為)
# Item: 本, Action: 本棚に収納する
#   RDF: (本棚, 収納する, 行為)
# Item: 本, Action: しおりを挟む
#   RDF: (しおり, 挟む, 行為)
# Item: 本, Action: 枕を使って寝転がる
#   RDF: (枕, て使う, 行為)
#   RDF: (枕, 寝転がる, 使用)
# Item: 本, Action: ブックライトを使う
#   RDF: (ライト, 使う, 行為)
#   RDF: (ブック, ライト, 使用)
# Item: 本, Action: カーテンを閉める
#   RDF: (カーテン, 閉める, 行為)
# Item: 本, Action: 本を積み上げてタワーを作る
#   RDF: (本, て積み上げる, 行為)
#   RDF: (タワー, 作る, 行為)
#   RDF: (本, タワー, 使用)
# Item: 本, Action: 本でドミノをする
#   RDF: (本, する, 行為)
#   RDF: (ドミノ, する, 行為)
#   RDF: (本, ドミノ, 使用)
# Item: 本, Action: 本のページで折り紙をする
#   RDF: (ページ, する, 行為)
#   RDF: (折り紙, する, 行為)
#   RDF: (本, ページ, 使用)
#   RDF: (本, 折り紙, 使用)
#   RDF: (ページ, 折り紙, 使用)
# Item: 本, Action: 本の中にメッセージを隠す
#   RDF: (中, 隠す, 行為)
#   RDF: (メッセージ, 隠す, 行為)
#   RDF: (本, 中, 使用)
#   RDF: (本, メッセージ, 使用)
#   RDF: (中, メッセージ, 使用)
# Item: 本, Action: 本を開いて隠れる
#   RDF: (本, て開く, 行為)
# Item: 本, Action: 本を使って積み木をする
#   RDF: (本, て使う, 行為)
#   RDF: (積み木, する, 行為)
#   RDF: (本, 積み木, 使用)
# Item: 本, Action: 本のページに絵を描く
#   RDF: (ページ, 描く, 行為)
#   RDF: (絵, 描く, 行為)
#   RDF: (本, ページ, 使用)
#   RDF: (本, 絵, 使用)
#   RDF: (ページ, 絵, 使用)
# Item: 本, Action: 本を使って仮面を作る
#   RDF: (本, て使う, 行為)
#   RDF: (仮面, 作る, 行為)
#   RDF: (本, 仮面, 使用)
# Item: 本, Action: 本を並べて道を作る
#   RDF: (本, て並べる, 行為)
#   RDF: (道, 作る, 行為)
#   RDF: (本, 道, 使用)
# Item: 本, Action: 本を使って家を作る
#   RDF: (本, て使う, 行為)
#   RDF: (家, 作る, 行為)
#   RDF: (本, 家, 使用)
# Item: 本, Action: 本を飛ばしてキャッチする
#   RDF: (本, て飛ばす, 行為)
# Item: 本, Action: 本でバランスゲームをする
#   RDF: (本, する, 行為)
#   RDF: (ゲーム, する, 行為)
#   RDF: (本, ゲーム, 使用)
# Item: 本, Action: 本の中に小物を隠す
#   RDF: (中, 隠す, 行為)
#   RDF: (小物, 隠す, 行為)
#   RDF: (本, 中, 使用)
#   RDF: (本, 小物, 使用)
#   RDF: (中, 小物, 使用)
# Item: 本, Action: 本を投げて距離を競う
#   RDF: (本, て投げる, 行為)
#   RDF: (距離, 競う, 行為)
#   RDF: (本, 距離, 使用)
# Item: 本, Action: 本を積み上げて競う
#   RDF: (本, て積み上げる, 行為)
# Item: 本, Action: 本でトンネルを作る
#   RDF: (本, 作る, 行為)
#   RDF: (トンネル, 作る, 行為)
#   RDF: (本, トンネル, 使用)
# Item: 本, Action: 本の中に手紙を隠す
#   RDF: (中, 隠す, 行為)
#   RDF: (手紙, 隠す, 行為)
#   RDF: (本, 中, 使用)
#   RDF: (本, 手紙, 使用)
#   RDF: (中, 手紙, 使用)
# Item: 本, Action: 本を重ねて高さを競う
#   RDF: (本, て重ねる, 行為)
#   RDF: (高, 競う, 行為)
# Item: 本, Action: 本のページを使って迷路を作る
#   RDF: (ページ, て使う, 行為)
#   RDF: (迷路, 作る, 行為)
#   RDF: (本, ページ, 使用)
#   RDF: (本, 迷路, 使用)
#   RDF: (ページ, 迷路, 使用)
# Item: 本, Action: 本で風を送る
#   RDF: (本, 送る, 行為)
#   RDF: (風, 送る, 行為)
#   RDF: (本, 風, 使用)
# Item: 本, Action: ページをめくる
# Item: 本, Action: 指をなめる
#   RDF: (指, なめる, 行為)
# Item: 本, Action: 本を持ち上げる
#   RDF: (本, 持ち上げる, 行為)
# Item: 本, Action: 本を傾ける
#   RDF: (本, 傾ける, 行為)
# Item: 本, Action: ページの角を折る
#   RDF: (角, 折る, 行為)
#   RDF: (ページ, 角, 使用)
# Item: 本, Action: 本を閉じる
#   RDF: (本, 閉じる, 行為)
# Item: 本, Action: 読む速度を変える
#   RDF: (速度, 変える, 行為)
# Item: 本, Action: 目をこする
#   RDF: (目, こする, 行為)
# Item: 本, Action: 読んでいる場所を見失う
#   RDF: (場所, 見失う, 行為)
# Item: 本, Action: しおりを挟む
#   RDF: (しおり, 挟む, 行為)
# Item: 本, Action: 本を机に置く
#   RDF: (本, 置く, 行為)
#   RDF: (机, 置く, 行為)
#   RDF: (本, 机, 使用)
# Item: 本, Action: 本を膝の上に置く
#   RDF: (本, 置く, 行為)
#   RDF: (上, 置く, 行為)
#   RDF: (本, 膝, 使用)
#   RDF: (本, 上, 使用)
#   RDF: (膝, 上, 使用)
# Item: 本, Action: 本を開いたまま置く
#   RDF: (本, 開くた, 行為)
#   RDF: (まま, 置く, 行為)
#   RDF: (本, まま, 使用)
# Item: 本, Action: ページを撫でる
#   RDF: (ページ, 撫でる, 行為)
# Item: 本, Action: 本を上下逆にする
#   RDF: (本, する, 行為)
#   RDF: (本, 上下, 使用)
# Item: 本, Action: 本を片手で持つ
#   RDF: (本, 持つ, 行為)
#   RDF: (片手, 持つ, 行為)
#   RDF: (本, 片手, 使用)
# Item: 本, Action: 頭をかく
# Item: 本, Action: 本の匂いを嗅ぐ
#   RDF: (匂い, 嗅ぐ, 行為)
#   RDF: (本, 匂い, 使用)
# Item: 本, Action: 本を指で叩く
#   RDF: (本, 叩く, 行為)
#   RDF: (指, 叩く, 行為)
#   RDF: (本, 指, 使用)
# Item: 本, Action: 本を手元に引き寄せる
#   RDF: (本, 引き寄せる, 行為)
#   RDF: (手元, 引き寄せる, 行為)
#   RDF: (本, 手元, 使用)
# Item: 本, Action: 本を落とす
#   RDF: (本, 落とす, 行為)
# Item: 本, Action: ページを破る
#   RDF: (ページ, 破る, 行為)
# Item: 本, Action: しおりをなくす
#   RDF: (しおり, なくす, 行為)
# Item: 本, Action: 本を濡らす
#   RDF: (本, 濡らす, 行為)
# Item: 本, Action: 本を汚す
#   RDF: (本, 汚す, 行為)
# Item: 本, Action: ページを折る
#   RDF: (ページ, 折る, 行為)
# Item: 本, Action: ページが引っかかる
# Item: 本, Action: 本を破る
#   RDF: (本, 破る, 行為)
# Item: 本, Action: 誤って本を閉じる
#   RDF: (本, 閉じる, 行為)
# Item: 本, Action: ページを抜かす
#   RDF: (ページ, 抜かす, 行為)
# Item: 本, Action: 本が開かない
# Item: 本, Action: 指を切る
#   RDF: (指, 切る, 行為)
# Item: 本, Action: 本を忘れる
#   RDF: (本, 忘れる, 行為)
# Item: 本, Action: 誤って線を引く
#   RDF: (線, 引く, 行為)
# Item: 本, Action: 付箋をなくす
#   RDF: (付箋, なくす, 行為)
# Item: 本, Action: 本を踏む
#   RDF: (本, 踏む, 行為)
# Item: 本, Action: 本を逆さまに読む
#   RDF: (本, 読む, 行為)
# Item: 本, Action: 本を紛失する
#   RDF: (本, 紛失する, 行為)
# Item: 本, Action: 本のカバーを破る
#   RDF: (カバー, 破る, 行為)
#   RDF: (本, カバー, 使用)
# Item: 本, Action: 本が見つからない
# Item: 本, Action: 本を貸す
#   RDF: (本, 貸す, 行為)
# Item: 本, Action: 本を借りる
#   RDF: (本, 借りる, 行為)
# Item: 本, Action: 本を共有する
#   RDF: (本, 共有する, 行為)
# Item: 本, Action: 本について話す
#   RDF: (本, 話す, 行為)
# Item: 本, Action: 本を推薦する
#   RDF: (本, 推薦する, 行為)
# Item: 本, Action: 本を贈る
#   RDF: (本, 贈る, 行為)
# Item: 本, Action: 本を返す
#   RDF: (本, 返す, 行為)
# Item: 本, Action: 一緒に読む
#   RDF: (一緒, 読む, 行為)
# Item: 本, Action: 読書会をする
#   RDF: (会, する, 行為)
#   RDF: (読書, 会, 使用)
# Item: 本, Action: 感想を交換する
#   RDF: (感想, 交換する, 行為)
# Item: 本, Action: 本を見せる
#   RDF: (本, 見せる, 行為)
# Item: 本, Action: 本を取り合う
#   RDF: (本, 取り合う, 行為)
# Item: 本, Action: 本について議論する
#   RDF: (本, 議論する, 行為)
# Item: 本, Action: 本を読む時間を作る
#   RDF: (本, 読む, 行為)
#   RDF: (時間, 作る, 行為)
#   RDF: (本, 時間, 使用)
# Item: 本, Action: 本をプレゼントする
#   RDF: (本, プレゼントする, 行為)
# Item: 本, Action: 本を交換する
#   RDF: (本, 交換する, 行為)
# Item: 本, Action: 本を置き忘れる
#   RDF: (本, 置く, 行為)
# Item: 本, Action: 本を探し合う
#   RDF: (本, 探す, 行為)
# Item: 本, Action: 本を手渡す
#   RDF: (本, 手渡す, 行為)
# Item: 本, Action: 本を分け合う
#   RDF: (本, 分け合う, 行為)
# Item: 電子書籍, Action: デバイスを手に取る
#   RDF: (デバイス, 取る, 行為)
#   RDF: (手, 取る, 行為)
#   RDF: (デバイス, 手, 使用)
# Item: 電子書籍, Action: 電源を入れる
#   RDF: (電源, 入れる, 行為)
# Item: 電子書籍, Action: アプリを開く
#   RDF: (アプリ, 開く, 行為)
# Item: 電子書籍, Action: 電子書籍を選ぶ
#   RDF: (書籍, 選ぶ, 行為)
#   RDF: (電子, 書籍, 使用)
# Item: 電子書籍, Action: ページをスワイプする
#   RDF: (ページ, スワイプする, 行為)
# Item: 電子書籍, Action: しおりを挿入する
#   RDF: (しおり, 挿入する, 行為)
# Item: 電子書籍, Action: 読むための姿勢をとる
#   RDF: (姿勢, とる, 行為)
#   RDF: (ため, 姿勢, 使用)
# Item: 電子書籍, Action: 画面の明るさを調整する
#   RDF: (明る, 調整する, 行為)
# Item: 電子書籍, Action: フォントサイズを変更する
#   RDF: (サイズ, 変更する, 行為)
#   RDF: (フォント, サイズ, 使用)
# Item: 電子書籍, Action: 辞書機能を使う
#   RDF: (機能, 使う, 行為)
#   RDF: (辞書, 機能, 使用)
# Item: 電子書籍, Action: メモを追加する
#   RDF: (メモ, 追加する, 行為)
# Item: 電子書籍, Action: ハイライトを引く
#   RDF: (ハイライト, 引く, 行為)
# Item: 電子書籍, Action: ページをブックマークする
#   RDF: (ページ, ブックマークする, 行為)
# Item: 電子書籍, Action: 再度開く
# Item: 電子書籍, Action: ノートを取る
#   RDF: (ノート, 取る, 行為)
# Item: 電子書籍, Action: 画面をスクロールする
#   RDF: (画面, スクロールする, 行為)
# Item: 電子書籍, Action: 一時停止する
# Item: 電子書籍, Action: 他のアプリを開く
#   RDF: (アプリ, 開く, 行為)
#   RDF: (他, アプリ, 使用)
# Item: 電子書籍, Action: デバイスを充電する
#   RDF: (デバイス, 充電する, 行為)
# Item: 電子書籍, Action: デバイスをシャットダウンする
#   RDF: (デバイス, シャットダウンする, 行為)
# Item: 電子書籍, Action: 読書灯で照らす
#   RDF: (灯, 照らす, 行為)
#   RDF: (読書, 灯, 使用)
# Item: 電子書籍, Action: 眼鏡をかける
#   RDF: (眼鏡, かける, 行為)
# Item: 電子書籍, Action: コーヒーを飲む
#   RDF: (コーヒー, 飲む, 行為)
# Item: 電子書籍, Action: 音楽を聴く
#   RDF: (音楽, 聴く, 行為)
# Item: 電子書籍, Action: ブランケットをかける
#   RDF: (ブランケット, かける, 行為)
# Item: 電子書籍, Action: 椅子に座る
#   RDF: (椅子, 座る, 行為)
# Item: 電子書籍, Action: ソファでくつろぐ
#   RDF: (ソファ, くつろぐ, 行為)
# Item: 電子書籍, Action: メモ帳にメモを取る
#   RDF: (メモ帳, 取る, 行為)
#   RDF: (メモ, 取る, 行為)
#   RDF: (メモ帳, メモ, 使用)
# Item: 電子書籍, Action: ペンを使ってノートを取る
#   RDF: (ペン, て使う, 行為)
#   RDF: (ノート, 取る, 行為)
#   RDF: (ペン, ノート, 使用)
# Item: 電子書籍, Action: スマホで調べ物をする
#   RDF: (スマホ, する, 行為)
#   RDF: (調べ物, する, 行為)
#   RDF: (スマホ, 調べ物, 使用)
# Item: 電子書籍, Action: タブレットで関連情報を読む
#   RDF: (タブレット, 読む, 行為)
#   RDF: (情報, 読む, 行為)
#   RDF: (タブレット, 関連, 使用)
#   RDF: (タブレット, 情報, 使用)
#   RDF: (関連, 情報, 使用)
# Item: 電子書籍, Action: 時計を確認する
#   RDF: (時計, 確認する, 行為)
# Item: 電子書籍, Action: スナックを食べる
#   RDF: (スナック, 食べる, 行為)
# Item: 電子書籍, Action: デバイスカバーをかける
#   RDF: (カバー, かける, 行為)
#   RDF: (デバイス, カバー, 使用)
# Item: 電子書籍, Action: デバイススタンドを使用する
#   RDF: (スタンド, 使用する, 行為)
#   RDF: (デバイス, スタンド, 使用)
# Item: 電子書籍, Action: しおりを挿入する
#   RDF: (しおり, 挿入する, 行為)
# Item: 電子書籍, Action: 枕を使って寝転がる
#   RDF: (枕, て使う, 行為)
#   RDF: (枕, 寝転がる, 使用)
# Item: 電子書籍, Action: ブックライトを使う
#   RDF: (ライト, 使う, 行為)
#   RDF: (ブック, ライト, 使用)
# Item: 電子書籍, Action: カーテンを閉める
#   RDF: (カーテン, 閉める, 行為)
# Item: 電子書籍, Action: イヤホンを使う
#   RDF: (イヤホン, 使う, 行為)
# Item: 電子書籍, Action: デバイスを積み上げてタワーを作る
#   RDF: (デバイス, て積み上げる, 行為)
#   RDF: (タワー, 作る, 行為)
#   RDF: (デバイス, タワー, 使用)
# Item: 電子書籍, Action: デバイスでドミノをする
#   RDF: (デバイス, する, 行為)
#   RDF: (ドミノ, する, 行為)
#   RDF: (デバイス, ドミノ, 使用)
# Item: 電子書籍, Action: スクリーンショットを撮る
#   RDF: (スクリーンショット, 撮る, 行為)
# Item: 電子書籍, Action: デバイスを隠す
#   RDF: (デバイス, 隠す, 行為)
# Item: 電子書籍, Action: デバイスを開いて隠れる
#   RDF: (デバイス, て開く, 行為)
# Item: 電子書籍, Action: デバイスで積み木をする
#   RDF: (デバイス, する, 行為)
#   RDF: (積み木, する, 行為)
#   RDF: (デバイス, 積み木, 使用)
# Item: 電子書籍, Action: 画面に絵を描く
#   RDF: (画面, 描く, 行為)
#   RDF: (絵, 描く, 行為)
#   RDF: (画面, 絵, 使用)
# Item: 電子書籍, Action: デバイスを使って仮面を作る
#   RDF: (デバイス, て使う, 行為)
#   RDF: (仮面, 作る, 行為)
#   RDF: (デバイス, 仮面, 使用)
# Item: 電子書籍, Action: デバイスを並べて道を作る
#   RDF: (デバイス, て並べる, 行為)
#   RDF: (道, 作る, 行為)
#   RDF: (デバイス, 道, 使用)
# Item: 電子書籍, Action: デバイスで家を作る
#   RDF: (デバイス, 作る, 行為)
#   RDF: (家, 作る, 行為)
#   RDF: (デバイス, 家, 使用)
# Item: 電子書籍, Action: デバイスを飛ばしてキャッチする
#   RDF: (デバイス, て飛ばす, 行為)
# Item: 電子書籍, Action: デバイスでバランスゲームをする
#   RDF: (デバイス, する, 行為)
#   RDF: (ゲーム, する, 行為)
#   RDF: (デバイス, バランス, 使用)
#   RDF: (デバイス, ゲーム, 使用)
#   RDF: (バランス, ゲーム, 使用)
# Item: 電子書籍, Action: デバイスに小物を隠す
#   RDF: (デバイス, 隠す, 行為)
#   RDF: (小物, 隠す, 行為)
#   RDF: (デバイス, 小物, 使用)
# Item: 電子書籍, Action: デバイスを投げて距離を競う
#   RDF: (デバイス, て投げる, 行為)
#   RDF: (距離, 競う, 行為)
#   RDF: (デバイス, 距離, 使用)
# Item: 電子書籍, Action: デバイスを積み上げて競う
#   RDF: (デバイス, て積み上げる, 行為)
# Item: 電子書籍, Action: デバイスでトンネルを作る
#   RDF: (デバイス, 作る, 行為)
#   RDF: (トンネル, 作る, 行為)
#   RDF: (デバイス, トンネル, 使用)
# Item: 電子書籍, Action: デバイスに手紙を隠す
#   RDF: (デバイス, 隠す, 行為)
#   RDF: (手紙, 隠す, 行為)
#   RDF: (デバイス, 手紙, 使用)
# Item: 電子書籍, Action: デバイスを重ねて高さを競う
#   RDF: (デバイス, て重ねる, 行為)
#   RDF: (高, 競う, 行為)
# Item: 電子書籍, Action: デバイスで迷路を作る
#   RDF: (デバイス, 作る, 行為)
#   RDF: (迷路, 作る, 行為)
#   RDF: (デバイス, 迷路, 使用)
# Item: 電子書籍, Action: デバイスで風を送る
#   RDF: (デバイス, 送る, 行為)
#   RDF: (風, 送る, 行為)
#   RDF: (デバイス, 風, 使用)
# Item: 電子書籍, Action: ページをスワイプする
#   RDF: (ページ, スワイプする, 行為)
# Item: 電子書籍, Action: 画面をタップする
#   RDF: (画面, タップする, 行為)
# Item: 電子書籍, Action: デバイスを持ち上げる
#   RDF: (デバイス, 持ち上げる, 行為)
# Item: 電子書籍, Action: デバイスを傾ける
#   RDF: (デバイス, 傾ける, 行為)
# Item: 電子書籍, Action: ページを閉じる
#   RDF: (ページ, 閉じる, 行為)
# Item: 電子書籍, Action: 読む速度を変える
#   RDF: (速度, 変える, 行為)
# Item: 電子書籍, Action: 目をこする
#   RDF: (目, こする, 行為)
# Item: 電子書籍, Action: 読んでいる場所を見失う
#   RDF: (場所, 見失う, 行為)
# Item: 電子書籍, Action: しおりを挿入する
#   RDF: (しおり, 挿入する, 行為)
# Item: 電子書籍, Action: デバイスを机に置く
#   RDF: (デバイス, 置く, 行為)
#   RDF: (机, 置く, 行為)
#   RDF: (デバイス, 机, 使用)
# Item: 電子書籍, Action: デバイスを膝の上に置く
#   RDF: (デバイス, 置く, 行為)
#   RDF: (上, 置く, 行為)
#   RDF: (デバイス, 膝, 使用)
#   RDF: (デバイス, 上, 使用)
#   RDF: (膝, 上, 使用)
# Item: 電子書籍, Action: デバイスを開いたまま置く
#   RDF: (デバイス, 開くた, 行為)
#   RDF: (まま, 置く, 行為)
#   RDF: (デバイス, まま, 使用)
# Item: 電子書籍, Action: 画面を撫でる
#   RDF: (画面, 撫でる, 行為)
# Item: 電子書籍, Action: デバイスを上下逆にする
#   RDF: (デバイス, する, 行為)
#   RDF: (デバイス, 上下, 使用)
# Item: 電子書籍, Action: デバイスを片手で持つ
#   RDF: (デバイス, 持つ, 行為)
#   RDF: (片手, 持つ, 行為)
#   RDF: (デバイス, 片手, 使用)
# Item: 電子書籍, Action: 頭をかく
# Item: 電子書籍, Action: 画面の匂いを嗅ぐ
#   RDF: (匂い, 嗅ぐ, 行為)
#   RDF: (画面, 匂い, 使用)
# Item: 電子書籍, Action: デバイスを指で叩く
#   RDF: (デバイス, 叩く, 行為)
#   RDF: (指, 叩く, 行為)
#   RDF: (デバイス, 指, 使用)
# Item: 電子書籍, Action: デバイスを手元に引き寄せる
#   RDF: (デバイス, 引き寄せる, 行為)
#   RDF: (手元, 引き寄せる, 行為)
#   RDF: (デバイス, 手元, 使用)
# Item: 電子書籍, Action: デバイスを落とす
#   RDF: (デバイス, 落とす, 行為)
# Item: 電子書籍, Action: 画面を割る
#   RDF: (画面, 割る, 行為)
# Item: 電子書籍, Action: しおりをなくす
#   RDF: (しおり, なくす, 行為)
# Item: 電子書籍, Action: デバイスを濡らす
#   RDF: (デバイス, 濡らす, 行為)
# Item: 電子書籍, Action: デバイスを汚す
#   RDF: (デバイス, 汚す, 行為)
# Item: 電子書籍, Action: デバイスが反応しない
# Item: 電子書籍, Action: 画面が引っかかる
# Item: 電子書籍, Action: 誤ってデバイスを閉じる
#   RDF: (デバイス, 閉じる, 行為)
# Item: 電子書籍, Action: ページを抜かす
#   RDF: (ページ, 抜かす, 行為)
# Item: 電子書籍, Action: デバイスが開かない
# Item: 電子書籍, Action: 指を切る
#   RDF: (指, 切る, 行為)
# Item: 電子書籍, Action: デバイスを忘れる
#   RDF: (デバイス, 忘れる, 行為)
# Item: 電子書籍, Action: 誤って操作する
# Item: 電子書籍, Action: 付箋をなくす
#   RDF: (付箋, なくす, 行為)
# Item: 電子書籍, Action: デバイスを踏む
#   RDF: (デバイス, 踏む, 行為)
# Item: 電子書籍, Action: デバイスを逆さまに読む
#   RDF: (デバイス, 読む, 行為)
# Item: 電子書籍, Action: デバイスを紛失する
#   RDF: (デバイス, 紛失する, 行為)
# Item: 電子書籍, Action: カバーを破る
#   RDF: (カバー, 破る, 行為)
# Item: 電子書籍, Action: デバイスが見つからない
# Item: 電子書籍, Action: デバイスが壊れる
# Item: 電子書籍, Action: デバイスを貸す
#   RDF: (デバイス, 貸す, 行為)
# Item: 電子書籍, Action: デバイスを借りる
#   RDF: (デバイス, 借りる, 行為)
# Item: 電子書籍, Action: デバイスを共有する
#   RDF: (デバイス, 共有する, 行為)
# Item: 電子書籍, Action: 電子書籍について話す
#   RDF: (書籍, 話す, 行為)
#   RDF: (電子, 書籍, 使用)
# Item: 電子書籍, Action: 電子書籍を推薦する
#   RDF: (書籍, 推薦する, 行為)
#   RDF: (電子, 書籍, 使用)
# Item: 電子書籍, Action: 電子書籍を贈る
#   RDF: (書籍, 贈る, 行為)
#   RDF: (電子, 書籍, 使用)
# Item: 電子書籍, Action: 電子書籍を返す
#   RDF: (書籍, 返す, 行為)
#   RDF: (電子, 書籍, 使用)
# Item: 電子書籍, Action: 一緒に読む
#   RDF: (一緒, 読む, 行為)
# Item: 電子書籍, Action: 読書会をする
#   RDF: (会, する, 行為)
#   RDF: (読書, 会, 使用)
# Item: 電子書籍, Action: 感想を交換する
#   RDF: (感想, 交換する, 行為)
# Item: 電子書籍, Action: 電子書籍を見せる
#   RDF: (書籍, 見せる, 行為)
#   RDF: (電子, 書籍, 使用)
# Item: 電子書籍, Action: デバイスを取り合う
#   RDF: (デバイス, 取り合う, 行為)
# Item: 電子書籍, Action: 電子書籍について議論する
#   RDF: (書籍, 議論する, 行為)
#   RDF: (電子, 書籍, 使用)
# Item: 電子書籍, Action: 電子書籍を読む時間を作る
#   RDF: (書籍, 読む, 行為)
#   RDF: (時間, 作る, 行為)
#   RDF: (電子, 書籍, 使用)
#   RDF: (電子, 時間, 使用)
#   RDF: (書籍, 時間, 使用)
# Item: 電子書籍, Action: 電子書籍をプレゼントする
#   RDF: (書籍, プレゼントする, 行為)
#   RDF: (電子, 書籍, 使用)
# Item: 電子書籍, Action: 電子書籍を交換する
#   RDF: (書籍, 交換する, 行為)
#   RDF: (電子, 書籍, 使用)
# Item: 電子書籍, Action: デバイスを置き忘れる
#   RDF: (デバイス, 置く, 行為)
# Item: 電子書籍, Action: デバイスを探し合う
#   RDF: (デバイス, 探す, 行為)
# Item: 電子書籍, Action: デバイスを手渡す
#   RDF: (デバイス, 手渡す, 行為)
# Item: 電子書籍, Action: デバイスを分け合う
#   RDF: (デバイス, 分け合う, 行為)
# Item: 紙の地図, Action: 地図を広げる
#   RDF: (地図, 広げる, 行為)
# Item: 紙の地図, Action: 現在地を確認する
#   RDF: (現在地, 確認する, 行為)
# Item: 紙の地図, Action: 目的地を探す
#   RDF: (目的地, 探す, 行為)
# Item: 紙の地図, Action: ルートを確認する
#   RDF: (ルート, 確認する, 行為)
# Item: 紙の地図, Action: ペンでルートを描く
#   RDF: (ペン, 描く, 行為)
#   RDF: (ルート, 描く, 行為)
#   RDF: (ペン, ルート, 使用)
# Item: 紙の地図, Action: 折り目をつける
#   RDF: (折り目, つける, 行為)
# Item: 紙の地図, Action: 地図を折りたたむ
#   RDF: (地図, 折りたたむ, 行為)
# Item: 紙の地図, Action: ポケットに入れる
#   RDF: (ポケット, 入れる, 行為)
# Item: 紙の地図, Action: メモを取る
#   RDF: (メモ, 取る, 行為)
# Item: 紙の地図, Action: 場所の名前を確認する
#   RDF: (名前, 確認する, 行為)
#   RDF: (場所, 名前, 使用)
# Item: 紙の地図, Action: 地図の凡例を見る
#   RDF: (凡例, 見る, 行為)
#   RDF: (地図, 凡例, 使用)
# Item: 紙の地図, Action: 方角を確認する
#   RDF: (方角, 確認する, 行為)
# Item: 紙の地図, Action: 周囲の地形を見る
#   RDF: (地形, 見る, 行為)
#   RDF: (周囲, 地形, 使用)
# Item: 紙の地図, Action: 交通手段を考える
#   RDF: (交通手段, 考える, 行為)
# Item: 紙の地図, Action: 地図を回転させる
#   RDF: (地図, 回転せる, 行為)
# Item: 紙の地図, Action: ルートを覚える
#   RDF: (ルート, 覚える, 行為)
# Item: 紙の地図, Action: 標高を確認する
#   RDF: (標高, 確認する, 行為)
# Item: 紙の地図, Action: 距離を測る
#   RDF: (距離, 測る, 行為)
# Item: 紙の地図, Action: 地図を見直す
#   RDF: (地図, 見直す, 行為)
# Item: 紙の地図, Action: 地図を保存する
#   RDF: (地図, 保存する, 行為)
# Item: 紙の地図, Action: コンパスを使う
#   RDF: (コンパス, 使う, 行為)
# Item: 紙の地図, Action: ペンでメモを取る
#   RDF: (ペン, 取る, 行為)
#   RDF: (メモ, 取る, 行為)
#   RDF: (ペン, メモ, 使用)
# Item: 紙の地図, Action: ノートに転記する
#   RDF: (ノート, 転記する, 行為)
# Item: 紙の地図, Action: スマホで現在地を確認する
#   RDF: (スマホ, 確認する, 行為)
#   RDF: (現在地, 確認する, 行為)
#   RDF: (スマホ, 現在地, 使用)
# Item: 紙の地図, Action: カメラで写真を撮る
#   RDF: (カメラ, 撮る, 行為)
#   RDF: (写真, 撮る, 行為)
#   RDF: (カメラ, 写真, 使用)
# Item: 紙の地図, Action: ルーペで細部を見る
#   RDF: (ルーペ, 見る, 行為)
#   RDF: (細部, 見る, 行為)
#   RDF: (ルーペ, 細部, 使用)
# Item: 紙の地図, Action: GPSデバイスと併用する
#   RDF: (デバイス, 併用する, 行為)
#   RDF: (GPS, デバイス, 使用)
# Item: 紙の地図, Action: ライトを使って照らす
#   RDF: (ライト, て使う, 行為)
# Item: 紙の地図, Action: 双眼鏡で遠くを見る
#   RDF: (双眼鏡, 見る, 行為)
#   RDF: (遠く, 見る, 行為)
#   RDF: (双眼鏡, 遠く, 使用)
# Item: 紙の地図, Action: メガネをかける
#   RDF: (メガネ, かける, 行為)
# Item: 紙の地図, Action: 傘を使う
#   RDF: (傘, 使う, 行為)
# Item: 紙の地図, Action: 飲み物を飲む
#   RDF: (飲み物, 飲む, 行為)
# Item: 紙の地図, Action: リュックにしまう
#   RDF: (リュック, しまう, 行為)
# Item: 紙の地図, Action: 手袋をはめる
#   RDF: (手袋, はめる, 行為)
# Item: 紙の地図, Action: マーカーで印をつける
#   RDF: (マーカー, つける, 行為)
#   RDF: (印, つける, 行為)
#   RDF: (マーカー, 印, 使用)
# Item: 紙の地図, Action: ノートPCで調べ物をする
#   RDF: (ノートPC, する, 行為)
#   RDF: (調べ物, する, 行為)
# Item: 紙の地図, Action: 座って確認する
# Item: 紙の地図, Action: テーブルに広げる
#   RDF: (テーブル, 広げる, 行為)
# Item: 紙の地図, Action: 他の地図と比較する
#   RDF: (地図, 比較する, 行為)
#   RDF: (他, 地図, 使用)
# Item: 紙の地図, Action: タブレットで情報を調べる
#   RDF: (タブレット, 調べる, 行為)
#   RDF: (情報, 調べる, 行為)
#   RDF: (タブレット, 情報, 使用)
# Item: 紙の地図, Action: 紙飛行機を作る
#   RDF: (飛行機, 作る, 行為)
#   RDF: (紙, 飛行機, 使用)
# Item: 紙の地図, Action: 折り紙をする
#   RDF: (折り紙, する, 行為)
# Item: 紙の地図, Action: 地図でドミノをする
#   RDF: (地図, する, 行為)
#   RDF: (ドミノ, する, 行為)
#   RDF: (地図, ドミノ, 使用)
# Item: 紙の地図, Action: 地図を使って宝探しゲームをする
#   RDF: (地図, て使う, 行為)
#   RDF: (ゲーム, する, 行為)
#   RDF: (地図, 宝探し, 使用)
#   RDF: (地図, ゲーム, 使用)
#   RDF: (宝探し, ゲーム, 使用)
# Item: 紙の地図, Action: 地図を塗り絵にする
#   RDF: (地図, する, 行為)
#   RDF: (塗り絵, する, 行為)
#   RDF: (地図, 塗り絵, 使用)
# Item: 紙の地図, Action: 地図をパズルにする
#   RDF: (地図, する, 行為)
#   RDF: (パズル, する, 行為)
#   RDF: (地図, パズル, 使用)
# Item: 紙の地図, Action: 地図を使ってかくれんぼをする
#   RDF: (地図, て使う, 行為)
#   RDF: (かくれんぼ, する, 行為)
#   RDF: (地図, かくれんぼ, 使用)
# Item: 紙の地図, Action: 地図をマントにする
#   RDF: (地図, する, 行為)
#   RDF: (マント, する, 行為)
#   RDF: (地図, マント, 使用)
# Item: 紙の地図, Action: 地図を切り抜いてコラージュを作る
#   RDF: (地図, て切り抜く, 行為)
#   RDF: (コラージュ, 作る, 行為)
#   RDF: (地図, コラージュ, 使用)
# Item: 紙の地図, Action: 地図を使って帽子を作る
#   RDF: (地図, て使う, 行為)
#   RDF: (帽子, 作る, 行為)
#   RDF: (地図, 帽子, 使用)
# Item: 紙の地図, Action: 地図で船を作る
#   RDF: (地図, 作る, 行為)
#   RDF: (船, 作る, 行為)
#   RDF: (地図, 船, 使用)
# Item: 紙の地図, Action: 地図で風車を作る
#   RDF: (地図, 作る, 行為)
#   RDF: (風車, 作る, 行為)
#   RDF: (地図, 風車, 使用)
# Item: 紙の地図, Action: 地図で仮面を作る
#   RDF: (地図, 作る, 行為)
#   RDF: (仮面, 作る, 行為)
#   RDF: (地図, 仮面, 使用)
# Item: 紙の地図, Action: 地図でオリガミの動物を作る
#   RDF: (地図, 作る, 行為)
#   RDF: (動物, 作る, 行為)
#   RDF: (地図, オリガミ, 使用)
#   RDF: (地図, 動物, 使用)
#   RDF: (オリガミ, 動物, 使用)
# Item: 紙の地図, Action: 地図を丸めて棒にする
#   RDF: (地図, て丸める, 行為)
#   RDF: (棒, する, 行為)
#   RDF: (地図, 棒, 使用)
# Item: 紙の地図, Action: 地図を使って紙相撲をする
#   RDF: (地図, て使う, 行為)
#   RDF: (紙相撲, する, 行為)
#   RDF: (地図, 紙相撲, 使用)
# Item: 紙の地図, Action: 地図を使って迷路を作る
#   RDF: (地図, て使う, 行為)
#   RDF: (迷路, 作る, 行為)
#   RDF: (地図, 迷路, 使用)
# Item: 紙の地図, Action: 地図で壁飾りを作る
#   RDF: (地図, 作る, 行為)
#   RDF: (壁飾り, 作る, 行為)
#   RDF: (地図, 壁飾り, 使用)
# Item: 紙の地図, Action: 地図を使って道を作る
#   RDF: (地図, て使う, 行為)
#   RDF: (道, 作る, 行為)
#   RDF: (地図, 道, 使用)
# Item: 紙の地図, Action: 地図を貼り合わせて大きな地図を作る
#   RDF: (地図, て貼り合わせる, 行為)
#   RDF: (地図, 作る, 行為)
#   RDF: (地図, 地図, 使用)
# Item: 紙の地図, Action: 地図を折りたたむ
#   RDF: (地図, 折りたたむ, 行為)
# Item: 紙の地図, Action: 地図を広げる
#   RDF: (地図, 広げる, 行為)
# Item: 紙の地図, Action: 地図を回転させる
#   RDF: (地図, 回転せる, 行為)
# Item: 紙の地図, Action: 現在地を探す
#   RDF: (現在地, 探す, 行為)
# Item: 紙の地図, Action: 目的地を探す
#   RDF: (目的地, 探す, 行為)
# Item: 紙の地図, Action: 地図を持ち上げる
#   RDF: (地図, 持ち上げる, 行為)
# Item: 紙の地図, Action: 地図を見失う
#   RDF: (地図, 見失う, 行為)
# Item: 紙の地図, Action: 地図を落とす
#   RDF: (地図, 落とす, 行為)
# Item: 紙の地図, Action: ページをめくるように扱う
#   RDF: (ページ, めくるに, 行為)
# Item: 紙の地図, Action: 指で地図を指す
#   RDF: (指, 指す, 行為)
#   RDF: (地図, 指す, 行為)
#   RDF: (指, 地図, 使用)
# Item: 紙の地図, Action: 地図を撫でる
#   RDF: (地図, 撫でる, 行為)
# Item: 紙の地図, Action: 地図を手元に引き寄せる
#   RDF: (地図, 引き寄せる, 行為)
#   RDF: (手元, 引き寄せる, 行為)
#   RDF: (地図, 手元, 使用)
# Item: 紙の地図, Action: 地図をたたむ
#   RDF: (地図, たたむ, 使用)
# Item: 紙の地図, Action: 地図を振る
#   RDF: (地図, 振る, 行為)
# Item: 紙の地図, Action: 地図の端を折る
#   RDF: (端, 折る, 行為)
#   RDF: (地図, 端, 使用)
# Item: 紙の地図, Action: 地図を握りしめる
#   RDF: (地図, 握りしめる, 行為)
# Item: 紙の地図, Action: 地図の匂いを嗅ぐ
#   RDF: (匂い, 嗅ぐ, 行為)
#   RDF: (地図, 匂い, 使用)
# Item: 紙の地図, Action: 地図を丸める
#   RDF: (地図, 丸める, 行為)
# Item: 紙の地図, Action: 地図を置き忘れる
#   RDF: (地図, 置く, 行為)
# Item: 紙の地図, Action: 地図を見つける
#   RDF: (地図, 見つける, 行為)
# Item: 紙の地図, Action: 地図を破る
#   RDF: (地図, 破る, 行為)
# Item: 紙の地図, Action: 地図を濡らす
#   RDF: (地図, 濡らす, 行為)
# Item: 紙の地図, Action: 地図を汚す
#   RDF: (地図, 汚す, 行為)
# Item: 紙の地図, Action: 地図を風で飛ばされる
#   RDF: (地図, 飛ばすれる, 行為)
#   RDF: (風, 飛ばすれる, 行為)
#   RDF: (地図, 風, 使用)
# Item: 紙の地図, Action: 地図を見失う
#   RDF: (地図, 見失う, 行為)
# Item: 紙の地図, Action: 地図を折り間違える
#   RDF: (地図, 折る, 行為)
# Item: 紙の地図, Action: 地図をなくす
#   RDF: (地図, なくす, 行為)
# Item: 紙の地図, Action: 地図を踏む
#   RDF: (地図, 踏む, 行為)
# Item: 紙の地図, Action: 地図を間違って描く
#   RDF: (地図, て間違う, 行為)
# Item: 紙の地図, Action: 地図を誤って破る
#   RDF: (地図, て誤る, 行為)
# Item: 紙の地図, Action: 地図を落とす
#   RDF: (地図, 落とす, 行為)
# Item: 紙の地図, Action: 地図が反対になる
# Item: 紙の地図, Action: 地図を引っ掛ける
#   RDF: (地図, 引っ掛ける, 行為)
# Item: 紙の地図, Action: 地図を破損する
#   RDF: (地図, 破損する, 行為)
# Item: 紙の地図, Action: 地図が飛び散る
# Item: 紙の地図, Action: 地図を忘れる
#   RDF: (地図, 忘れる, 行為)
# Item: 紙の地図, Action: 地図を他人に取られる
#   RDF: (地図, 取るれる, 行為)
#   RDF: (他人, 取るれる, 行為)
#   RDF: (地図, 他人, 使用)
# Item: 紙の地図, Action: 地図を置き忘れる
#   RDF: (地図, 置く, 行為)
# Item: 紙の地図, Action: 地図が見つからない
# Item: 紙の地図, Action: 地図を紛失する
#   RDF: (地図, 紛失する, 行為)
# Item: 紙の地図, Action: 地図を共有する
#   RDF: (地図, 共有する, 行為)
# Item: 紙の地図, Action: 地図について話す
#   RDF: (地図, 話す, 行為)
# Item: 紙の地図, Action: 地図を贈る
#   RDF: (地図, 贈る, 行為)
# Item: 紙の地図, Action: 地図を返す
#   RDF: (地図, 返す, 行為)
# Item: 紙の地図, Action: 地図を一緒に読む
#   RDF: (地図, 読む, 行為)
#   RDF: (一緒, 読む, 行為)
#   RDF: (地図, 一緒, 使用)
# Item: 紙の地図, Action: 地図を使って議論する
#   RDF: (地図, て使う, 行為)
# Item: 紙の地図, Action: 地図を貸す
#   RDF: (地図, 貸す, 行為)
# Item: 紙の地図, Action: 地図を借りる
#   RDF: (地図, 借りる, 行為)
# Item: 紙の地図, Action: 地図を見せる
#   RDF: (地図, 見せる, 行為)
# Item: 紙の地図, Action: 地図を取り合う
#   RDF: (地図, 取り合う, 行為)
# Item: 紙の地図, Action: 地図を探し合う
#   RDF: (地図, 探す, 行為)
# Item: 紙の地図, Action: 地図を手渡す
#   RDF: (地図, 手渡す, 行為)
# Item: 紙の地図, Action: 地図を交換する
#   RDF: (地図, 交換する, 行為)
# Item: 紙の地図, Action: 地図の場所を教える
#   RDF: (場所, 教える, 行為)
#   RDF: (地図, 場所, 使用)
# Item: 紙の地図, Action: 地図について感想を述べる
#   RDF: (地図, 述べる, 行為)
#   RDF: (感想, 述べる, 行為)
#   RDF: (地図, 感想, 使用)
# Item: 紙の地図, Action: 地図を使って読書会をする
#   RDF: (地図, て使う, 行為)
#   RDF: (会, する, 行為)
#   RDF: (地図, 読書, 使用)
#   RDF: (地図, 会, 使用)
#   RDF: (読書, 会, 使用)
# Item: 紙の地図, Action: 地図を紹介する
#   RDF: (地図, 紹介する, 行為)
# Item: 紙の地図, Action: 地図を一緒に作る
#   RDF: (地図, 作る, 行為)
#   RDF: (一緒, 作る, 行為)
#   RDF: (地図, 一緒, 使用)
# Item: 紙の地図, Action: 地図を分け合う
#   RDF: (地図, 分け合う, 行為)
# Item: 紙の地図, Action: 地図を使って方向を指示する
#   RDF: (地図, て使う, 行為)
#   RDF: (方向, 指示する, 行為)
#   RDF: (地図, 方向, 使用)
# Item: 鍋, Action: 鍋を取り出す
#   RDF: (鍋, 取り出す, 行為)
# Item: 鍋, Action: 水を入れる
#   RDF: (水, 入れる, 行為)
# Item: 鍋, Action: 材料を入れる
#   RDF: (材料, 入れる, 行為)
# Item: 鍋, Action: 火をつける
#   RDF: (火, つける, 行為)
# Item: 鍋, Action: 沸騰させる
# Item: 鍋, Action: アクを取る
#   RDF: (アク, 取る, 行為)
# Item: 鍋, Action: 調味料を加える
#   RDF: (調味料, 加える, 行為)
# Item: 鍋, Action: 弱火にする
#   RDF: (弱火, する, 行為)
# Item: 鍋, Action: 蓋をする
#   RDF: (蓋, する, 行為)
# Item: 鍋, Action: 煮込む
# Item: 鍋, Action: かき混ぜる
# Item: 鍋, Action: 蓋を取る
#   RDF: (蓋, 取る, 行為)
# Item: 鍋, Action: 火を止める
#   RDF: (火, 止める, 行為)
# Item: 鍋, Action: 皿に盛る
#   RDF: (皿, 盛る, 行為)
# Item: 鍋, Action: 鍋を洗う
#   RDF: (鍋, 洗う, 行為)
# Item: 鍋, Action: 鍋を乾かす
#   RDF: (鍋, 乾かす, 行為)
# Item: 鍋, Action: 鍋をしまう
#   RDF: (鍋, しまう, 行為)
# Item: 鍋, Action: レシピを確認する
#   RDF: (レシピ, 確認する, 行為)
# Item: 鍋, Action: 鍋を温め直す
#   RDF: (鍋, 温め直す, 使用)
# Item: 鍋, Action: 鍋を移動する
#   RDF: (鍋, 移動する, 行為)
# Item: 鍋, Action: スプーンでかき混ぜる
#   RDF: (スプーン, かき混ぜる, 行為)
# Item: 鍋, Action: お玉で取り分ける
#   RDF: (玉, 取り分ける, 行為)
#   RDF: (お, 玉, 使用)
# Item: 鍋, Action: 蓋をする
#   RDF: (蓋, する, 行為)
# Item: 鍋, Action: コンロで火をつける
#   RDF: (コンロ, つける, 行為)
#   RDF: (火, つける, 行為)
#   RDF: (コンロ, 火, 使用)
# Item: 鍋, Action: レシピ本を読む
#   RDF: (本, 読む, 行為)
#   RDF: (レシピ, 本, 使用)
# Item: 鍋, Action: 調味料を入れる
#   RDF: (調味料, 入れる, 行為)
# Item: 鍋, Action: 皿に盛る
#   RDF: (皿, 盛る, 行為)
# Item: 鍋, Action: ナイフで切る
#   RDF: (ナイフ, 切る, 行為)
# Item: 鍋, Action: フォークで刺す
#   RDF: (フォーク, 刺す, 行為)
# Item: 鍋, Action: 鍋敷きを使う
#   RDF: (鍋敷き, 使う, 行為)
# Item: 鍋, Action: 鍋つかみを使う
#   RDF: (鍋つかみ, 使う, 行為)
# Item: 鍋, Action: 水を足す
#   RDF: (水, 足す, 行為)
# Item: 鍋, Action: タイマーをセットする
#   RDF: (タイマー, セットする, 行為)
# Item: 鍋, Action: 冷蔵庫から材料を出す
#   RDF: (冷蔵庫, 出す, 行為)
#   RDF: (材料, 出す, 行為)
#   RDF: (冷蔵庫, 材料, 使用)
# Item: 鍋, Action: 鍋を布巾で拭く
#   RDF: (鍋, 拭く, 行為)
#   RDF: (布巾, 拭く, 行為)
#   RDF: (鍋, 布巾, 使用)
# Item: 鍋, Action: 電子レンジで温める
#   RDF: (電子レンジ, 温める, 行為)
# Item: 鍋, Action: 包丁で切る
#   RDF: (包丁, 切る, 行為)
# Item: 鍋, Action: 箸で取り分ける
#   RDF: (箸, 取り分ける, 行為)
# Item: 鍋, Action: スープをすくう
#   RDF: (スープ, すくう, 行為)
# Item: 鍋, Action: 鍋をテーブルに運ぶ
#   RDF: (鍋, 運ぶ, 行為)
#   RDF: (テーブル, 運ぶ, 行為)
#   RDF: (鍋, テーブル, 使用)
# Item: 鍋, Action: 鍋を楽器にする
#   RDF: (鍋, する, 行為)
#   RDF: (楽器, する, 行為)
#   RDF: (鍋, 楽器, 使用)
# Item: 鍋, Action: 鍋でドラムを叩く
#   RDF: (鍋, 叩く, 行為)
#   RDF: (ドラム, 叩く, 行為)
#   RDF: (鍋, ドラム, 使用)
# Item: 鍋, Action: 鍋を帽子にする
#   RDF: (鍋, する, 行為)
#   RDF: (帽子, する, 行為)
#   RDF: (鍋, 帽子, 使用)
# Item: 鍋, Action: 鍋を振る
#   RDF: (鍋, 振る, 行為)
# Item: 鍋, Action: 鍋でボールを受ける
#   RDF: (鍋, 受ける, 行為)
#   RDF: (ボール, 受ける, 行為)
#   RDF: (鍋, ボール, 使用)
# Item: 鍋, Action: 鍋を使ってサッカー
#   RDF: (鍋, て使う, 行為)
#   RDF: (鍋, サッカー, 使用)
# Item: 鍋, Action: 鍋を使ってボウリング
#   RDF: (鍋, て使う, 行為)
# Item: 鍋, Action: 鍋を転がす
#   RDF: (鍋, 転がす, 行為)
# Item: 鍋, Action: 鍋で水遊び
#   RDF: (鍋, 水遊び, 使用)
# Item: 鍋, Action: 鍋におもちゃを入れる
#   RDF: (鍋, 入れる, 行為)
#   RDF: (おもちゃ, 入れる, 行為)
#   RDF: (鍋, おもちゃ, 使用)
# Item: 鍋, Action: 鍋を使って隠れんぼ
#   RDF: (鍋, て使う, 行為)
#   RDF: (鍋, 隠れんぼ, 使用)
# Item: 鍋, Action: 鍋を使って迷路を作る
#   RDF: (鍋, て使う, 行為)
#   RDF: (迷路, 作る, 行為)
#   RDF: (鍋, 迷路, 使用)
# Item: 鍋, Action: 鍋で風を送る
#   RDF: (鍋, 送る, 行為)
#   RDF: (風, 送る, 行為)
#   RDF: (鍋, 風, 使用)
# Item: 鍋, Action: 鍋でおもちゃを運ぶ
#   RDF: (鍋, 運ぶ, 行為)
#   RDF: (おもちゃ, 運ぶ, 行為)
#   RDF: (鍋, おもちゃ, 使用)
# Item: 鍋, Action: 鍋を積み上げる
#   RDF: (鍋, 積み上げる, 行為)
# Item: 鍋, Action: 鍋を重ねて高さを競う
#   RDF: (鍋, て重ねる, 行為)
#   RDF: (高, 競う, 行為)
# Item: 鍋, Action: 鍋を使ってかくれんぼ
#   RDF: (鍋, て使う, 行為)
# Item: 鍋, Action: 鍋でバランスゲーム
#   RDF: (鍋, ゲーム, 使用)
# Item: 鍋, Action: 鍋を使ってパズルを作る
#   RDF: (鍋, て使う, 行為)
#   RDF: (パズル, 作る, 行為)
#   RDF: (鍋, パズル, 使用)
# Item: 鍋, Action: 鍋を使っておもちゃを洗う
#   RDF: (鍋, て使う, 行為)
#   RDF: (おもちゃ, 洗う, 行為)
#   RDF: (鍋, おもちゃ, 使用)
# Item: 鍋, Action: 鍋をかき混ぜる
#   RDF: (鍋, かき混ぜる, 行為)
# Item: 鍋, Action: 鍋を振る
#   RDF: (鍋, 振る, 行為)
# Item: 鍋, Action: 鍋を傾ける
#   RDF: (鍋, 傾ける, 行為)
# Item: 鍋, Action: 鍋の蓋を取る
#   RDF: (蓋, 取る, 行為)
#   RDF: (鍋, 蓋, 使用)
# Item: 鍋, Action: 鍋を持ち上げる
#   RDF: (鍋, 持ち上げる, 行為)
# Item: 鍋, Action: 鍋を置く
#   RDF: (鍋, 置く, 行為)
# Item: 鍋, Action: 鍋を覗き込む
#   RDF: (鍋, 覗き込む, 行為)
# Item: 鍋, Action: 鍋を触る
#   RDF: (鍋, 触る, 行為)
# Item: 鍋, Action: 鍋を叩く
#   RDF: (鍋, 叩く, 行為)
# Item: 鍋, Action: 鍋を回す
#   RDF: (鍋, 回す, 行為)
# Item: 鍋, Action: 鍋を持つ手を変える
#   RDF: (鍋, 持つ, 行為)
#   RDF: (手, 変える, 行為)
#   RDF: (鍋, 手, 使用)
# Item: 鍋, Action: 鍋を拭く
#   RDF: (鍋, 拭く, 行為)
# Item: 鍋, Action: 鍋を開ける
#   RDF: (鍋, 開ける, 行為)
# Item: 鍋, Action: 鍋を閉じる
#   RDF: (鍋, 閉じる, 行為)
# Item: 鍋, Action: 鍋の中を確認する
#   RDF: (中, 確認する, 行為)
#   RDF: (鍋, 中, 使用)
# Item: 鍋, Action: 鍋を持ち替える
#   RDF: (鍋, 持ち替える, 行為)
# Item: 鍋, Action: 鍋を揺らす
#   RDF: (鍋, 揺らす, 行為)
# Item: 鍋, Action: 鍋を掴む
#   RDF: (鍋, 掴む, 行為)
# Item: 鍋, Action: 鍋を上下に動かす
#   RDF: (鍋, 動かす, 行為)
#   RDF: (鍋, 上下, 使用)
# Item: 鍋, Action: 鍋を熱する
#   RDF: (鍋, 熱する, 行為)
# Item: 鍋, Action: 鍋を落とす
#   RDF: (鍋, 落とす, 行為)
# Item: 鍋, Action: 鍋を焦がす
#   RDF: (鍋, 焦がす, 行為)
# Item: 鍋, Action: 鍋を割る
#   RDF: (鍋, 割る, 行為)
# Item: 鍋, Action: 鍋をひっくり返す
#   RDF: (鍋, ひっくり返す, 行為)
# Item: 鍋, Action: 鍋の中身をこぼす
#   RDF: (中身, こぼす, 行為)
#   RDF: (鍋, 中身, 使用)
# Item: 鍋, Action: 鍋を汚す
#   RDF: (鍋, 汚す, 行為)
# Item: 鍋, Action: 鍋の蓋をなくす
#   RDF: (蓋, なくす, 行為)
#   RDF: (鍋, 蓋, 使用)
# Item: 鍋, Action: 鍋を破損する
#   RDF: (鍋, 破損する, 行為)
# Item: 鍋, Action: 鍋を火傷する
#   RDF: (鍋, 火傷する, 行為)
# Item: 鍋, Action: 鍋を倒す
#   RDF: (鍋, 倒す, 行為)
# Item: 鍋, Action: 鍋を冷やす
#   RDF: (鍋, 冷やす, 行為)
# Item: 鍋, Action: 鍋を誤って操作する
#   RDF: (鍋, て誤る, 行為)
# Item: 鍋, Action: 鍋を割る
#   RDF: (鍋, 割る, 行為)
# Item: 鍋, Action: 鍋を吹きこぼす
#   RDF: (鍋, 吹きこぼす, 行為)
# Item: 鍋, Action: 鍋の取っ手を壊す
#   RDF: (取っ手, 壊す, 行為)
#   RDF: (鍋, 取っ手, 使用)
# Item: 鍋, Action: 鍋を誤って加熱する
#   RDF: (鍋, て誤る, 行為)
# Item: 鍋, Action: 鍋を触る
#   RDF: (鍋, 触る, 行為)
# Item: 鍋, Action: 鍋を焦がす
#   RDF: (鍋, 焦がす, 行為)
# Item: 鍋, Action: 鍋を取り違える
#   RDF: (鍋, 取り違える, 行為)
# Item: 鍋, Action: 鍋を誤って捨てる
#   RDF: (鍋, て誤る, 行為)
# Item: 鍋, Action: 鍋料理を一緒に作る
#   RDF: (鍋料理, 作る, 行為)
#   RDF: (一緒, 作る, 行為)
#   RDF: (鍋料理, 一緒, 使用)
# Item: 鍋, Action: 鍋を貸す
#   RDF: (鍋, 貸す, 行為)
# Item: 鍋, Action: 鍋を借りる
#   RDF: (鍋, 借りる, 行為)
# Item: 鍋, Action: 鍋を共有する
#   RDF: (鍋, 共有する, 行為)
# Item: 鍋, Action: 鍋料理を楽しむ
#   RDF: (鍋料理, 楽しむ, 行為)
# Item: 鍋, Action: 鍋のレシピを教える
#   RDF: (レシピ, 教える, 行為)
#   RDF: (鍋, レシピ, 使用)
# Item: 鍋, Action: 鍋の感想を言う
#   RDF: (感想, 言う, 行為)
#   RDF: (鍋, 感想, 使用)
# Item: 鍋, Action: 鍋を返す
#   RDF: (鍋, 返す, 行為)
# Item: 鍋, Action: 鍋を贈る
#   RDF: (鍋, 贈る, 行為)
# Item: 鍋, Action: 鍋を見せる
#   RDF: (鍋, 見せる, 行為)
# Item: 鍋, Action: 鍋を取り合う
#   RDF: (鍋, 取り合う, 行為)
# Item: 鍋, Action: 鍋について話す
#   RDF: (鍋, 話す, 行為)
# Item: 鍋, Action: 鍋を交換する
#   RDF: (鍋, 交換する, 行為)
# Item: 鍋, Action: 鍋を紹介する
#   RDF: (鍋, 紹介する, 行為)
# Item: 鍋, Action: 鍋を一緒に使う
#   RDF: (鍋, 使う, 行為)
#   RDF: (一緒, 使う, 行為)
#   RDF: (鍋, 一緒, 使用)
# Item: 鍋, Action: 鍋を探し合う
#   RDF: (鍋, 探す, 行為)
# Item: 鍋, Action: 鍋を手渡す
#   RDF: (鍋, 手渡す, 行為)
# Item: 鍋, Action: 鍋を洗い合う
#   RDF: (鍋, 洗い合う, 行為)
# Item: 鍋, Action: 鍋を使って料理を教える
#   RDF: (鍋, て使う, 行為)
#   RDF: (料理, 教える, 行為)
#   RDF: (鍋, 料理, 使用)
# Item: 鍋, Action: 鍋の使い方を説明する
#   RDF: (使い方, 説明する, 行為)
#   RDF: (鍋, 使い方, 使用)
# Item: 自動調理器, Action: 自動調理器を取り出す
#   RDF: (調理器, 取り出す, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 水を入れる
#   RDF: (水, 入れる, 行為)
# Item: 自動調理器, Action: 材料をセットする
#   RDF: (材料, セットする, 行為)
# Item: 自動調理器, Action: プログラムを選ぶ
#   RDF: (プログラム, 選ぶ, 行為)
# Item: 自動調理器, Action: 電源を入れる
#   RDF: (電源, 入れる, 行為)
# Item: 自動調理器, Action: 調理時間を設定する
#   RDF: (時間, 設定する, 行為)
#   RDF: (調理, 時間, 使用)
# Item: 自動調理器, Action: 蓋を閉める
#   RDF: (蓋, 閉める, 行為)
# Item: 自動調理器, Action: スタートボタンを押す
#   RDF: (ボタン, 押す, 行為)
#   RDF: (スタート, ボタン, 使用)
# Item: 自動調理器, Action: 調理過程を確認する
#   RDF: (過程, 確認する, 行為)
#   RDF: (調理, 過程, 使用)
# Item: 自動調理器, Action: アラームが鳴るのを待つ
# Item: 自動調理器, Action: 調理が完了する
# Item: 自動調理器, Action: 蓋を開ける
#   RDF: (蓋, 開ける, 行為)
# Item: 自動調理器, Action: 料理を取り出す
#   RDF: (料理, 取り出す, 行為)
# Item: 自動調理器, Action: 自動調理器を洗う
#   RDF: (調理器, 洗う, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を乾かす
#   RDF: (調理器, 乾かす, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器をしまう
#   RDF: (調理器, しまう, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: レシピを確認する
#   RDF: (レシピ, 確認する, 行為)
# Item: 自動調理器, Action: 自動調理器を温め直す
#   RDF: (調理器, 温め直す, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を移動する
#   RDF: (調理器, 移動する, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 操作マニュアルを確認する
#   RDF: (操作マニュアル, 確認する, 行為)
# Item: 自動調理器, Action: スプーンでかき混ぜる
#   RDF: (スプーン, かき混ぜる, 行為)
# Item: 自動調理器, Action: お玉で取り分ける
#   RDF: (玉, 取り分ける, 行為)
#   RDF: (お, 玉, 使用)
# Item: 自動調理器, Action: 蓋をする
#   RDF: (蓋, する, 行為)
# Item: 自動調理器, Action: コンロで火をつける
#   RDF: (コンロ, つける, 行為)
#   RDF: (火, つける, 行為)
#   RDF: (コンロ, 火, 使用)
# Item: 自動調理器, Action: レシピ本を読む
#   RDF: (本, 読む, 行為)
#   RDF: (レシピ, 本, 使用)
# Item: 自動調理器, Action: 調味料を入れる
#   RDF: (調味料, 入れる, 行為)
# Item: 自動調理器, Action: 皿に盛る
#   RDF: (皿, 盛る, 行為)
# Item: 自動調理器, Action: ナイフで切る
#   RDF: (ナイフ, 切る, 行為)
# Item: 自動調理器, Action: フォークで刺す
#   RDF: (フォーク, 刺す, 行為)
# Item: 自動調理器, Action: 鍋敷きを使う
#   RDF: (鍋敷き, 使う, 行為)
# Item: 自動調理器, Action: 鍋つかみを使う
#   RDF: (鍋つかみ, 使う, 行為)
# Item: 自動調理器, Action: 水を足す
#   RDF: (水, 足す, 行為)
# Item: 自動調理器, Action: タイマーをセットする
#   RDF: (タイマー, セットする, 行為)
# Item: 自動調理器, Action: 冷蔵庫から材料を出す
#   RDF: (冷蔵庫, 出す, 行為)
#   RDF: (材料, 出す, 行為)
#   RDF: (冷蔵庫, 材料, 使用)
# Item: 自動調理器, Action: 鍋を布巾で拭く
#   RDF: (鍋, 拭く, 行為)
#   RDF: (布巾, 拭く, 行為)
#   RDF: (鍋, 布巾, 使用)
# Item: 自動調理器, Action: 電子レンジで温める
#   RDF: (電子レンジ, 温める, 行為)
# Item: 自動調理器, Action: 包丁で切る
#   RDF: (包丁, 切る, 行為)
# Item: 自動調理器, Action: 箸で取り分ける
#   RDF: (箸, 取り分ける, 行為)
# Item: 自動調理器, Action: スープをすくう
#   RDF: (スープ, すくう, 行為)
# Item: 自動調理器, Action: テーブルに運ぶ
#   RDF: (テーブル, 運ぶ, 行為)
# Item: 自動調理器, Action: 自動調理器を楽器にする
#   RDF: (調理器, する, 行為)
#   RDF: (楽器, する, 行為)
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, 楽器, 使用)
#   RDF: (調理器, 楽器, 使用)
# Item: 自動調理器, Action: 自動調理器でドラムを叩く
#   RDF: (調理器, 叩く, 行為)
#   RDF: (ドラム, 叩く, 行為)
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, ドラム, 使用)
#   RDF: (調理器, ドラム, 使用)
# Item: 自動調理器, Action: 自動調理器を帽子にする
#   RDF: (調理器, する, 行為)
#   RDF: (帽子, する, 行為)
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, 帽子, 使用)
#   RDF: (調理器, 帽子, 使用)
# Item: 自動調理器, Action: 自動調理器を振る
#   RDF: (調理器, 振る, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器でボールを受ける
#   RDF: (調理器, 受ける, 行為)
#   RDF: (ボール, 受ける, 行為)
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, ボール, 使用)
#   RDF: (調理器, ボール, 使用)
# Item: 自動調理器, Action: 自動調理器を使ってサッカー
#   RDF: (調理器, て使う, 行為)
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, サッカー, 使用)
#   RDF: (調理器, サッカー, 使用)
# Item: 自動調理器, Action: 自動調理器を使ってボウリング
#   RDF: (調理器, て使う, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を転がす
#   RDF: (調理器, 転がす, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器で水遊び
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, 水遊び, 使用)
#   RDF: (調理器, 水遊び, 使用)
# Item: 自動調理器, Action: 自動調理器におもちゃを入れる
#   RDF: (調理器, 入れる, 行為)
#   RDF: (おもちゃ, 入れる, 行為)
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, おもちゃ, 使用)
#   RDF: (調理器, おもちゃ, 使用)
# Item: 自動調理器, Action: 自動調理器を使って隠れんぼ
#   RDF: (調理器, て使う, 行為)
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, 隠れんぼ, 使用)
#   RDF: (調理器, 隠れんぼ, 使用)
# Item: 自動調理器, Action: 自動調理器を使って迷路を作る
#   RDF: (調理器, て使う, 行為)
#   RDF: (迷路, 作る, 行為)
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, 迷路, 使用)
#   RDF: (調理器, 迷路, 使用)
# Item: 自動調理器, Action: 自動調理器で風を送る
#   RDF: (調理器, 送る, 行為)
#   RDF: (風, 送る, 行為)
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, 風, 使用)
#   RDF: (調理器, 風, 使用)
# Item: 自動調理器, Action: 自動調理器でおもちゃを運ぶ
#   RDF: (調理器, 運ぶ, 行為)
#   RDF: (おもちゃ, 運ぶ, 行為)
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, おもちゃ, 使用)
#   RDF: (調理器, おもちゃ, 使用)
# Item: 自動調理器, Action: 自動調理器を積み上げる
#   RDF: (調理器, 積み上げる, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を重ねて高さを競う
#   RDF: (調理器, て重ねる, 行為)
#   RDF: (高, 競う, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を使ってかくれんぼ
#   RDF: (調理器, て使う, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器でバランスゲーム
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, ゲーム, 使用)
#   RDF: (調理器, ゲーム, 使用)
# Item: 自動調理器, Action: 自動調理器を使ってパズルを作る
#   RDF: (調理器, て使う, 行為)
#   RDF: (パズル, 作る, 行為)
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, パズル, 使用)
#   RDF: (調理器, パズル, 使用)
# Item: 自動調理器, Action: 自動調理器を使っておもちゃを洗う
#   RDF: (調理器, て使う, 行為)
#   RDF: (おもちゃ, 洗う, 行為)
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, おもちゃ, 使用)
#   RDF: (調理器, おもちゃ, 使用)
# Item: 自動調理器, Action: 自動調理器をかき混ぜる
#   RDF: (調理器, かき混ぜる, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を振る
#   RDF: (調理器, 振る, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を傾ける
#   RDF: (調理器, 傾ける, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器の蓋を取る
#   RDF: (蓋, 取る, 行為)
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, 蓋, 使用)
#   RDF: (調理器, 蓋, 使用)
# Item: 自動調理器, Action: 自動調理器を持ち上げる
#   RDF: (調理器, 持ち上げる, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を置く
#   RDF: (調理器, 置く, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を覗き込む
#   RDF: (調理器, 覗き込む, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を触る
#   RDF: (調理器, 触る, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を叩く
#   RDF: (調理器, 叩く, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を回す
#   RDF: (調理器, 回す, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を持つ手を変える
#   RDF: (調理器, 持つ, 行為)
#   RDF: (手, 変える, 行為)
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, 手, 使用)
#   RDF: (調理器, 手, 使用)
# Item: 自動調理器, Action: 自動調理器を拭く
#   RDF: (調理器, 拭く, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を開ける
#   RDF: (調理器, 開ける, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を閉じる
#   RDF: (調理器, 閉じる, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器の中を確認する
#   RDF: (中, 確認する, 行為)
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, 中, 使用)
#   RDF: (調理器, 中, 使用)
# Item: 自動調理器, Action: 自動調理器を持ち替える
#   RDF: (調理器, 持ち替える, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を揺らす
#   RDF: (調理器, 揺らす, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を掴む
#   RDF: (調理器, 掴む, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を上下に動かす
#   RDF: (調理器, 動かす, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を熱する
#   RDF: (調理器, 熱する, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を落とす
#   RDF: (調理器, 落とす, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を焦がす
#   RDF: (調理器, 焦がす, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を割る
#   RDF: (調理器, 割る, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器をひっくり返す
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器の中身をこぼす
#   RDF: (中身, こぼす, 行為)
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, 中身, 使用)
#   RDF: (調理器, 中身, 使用)
# Item: 自動調理器, Action: 自動調理器を汚す
#   RDF: (調理器, 汚す, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器の蓋をなくす
#   RDF: (蓋, なくす, 行為)
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, 蓋, 使用)
#   RDF: (調理器, 蓋, 使用)
# Item: 自動調理器, Action: 自動調理器を破損する
#   RDF: (調理器, 破損する, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を火傷する
#   RDF: (調理器, 火傷する, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を倒す
#   RDF: (調理器, 倒す, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を冷やす
#   RDF: (調理器, 冷やす, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を誤って操作する
#   RDF: (調理器, て誤る, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を割る
#   RDF: (調理器, 割る, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を吹きこぼす
#   RDF: (調理器, 吹きこぼす, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器の取っ手を壊す
#   RDF: (取っ手, 壊す, 行為)
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, 取っ手, 使用)
#   RDF: (調理器, 取っ手, 使用)
# Item: 自動調理器, Action: 自動調理器を誤って加熱する
#   RDF: (調理器, て誤る, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を触る
#   RDF: (調理器, 触る, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を焦がす
#   RDF: (調理器, 焦がす, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を取り違える
#   RDF: (調理器, 取り違える, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を誤って捨てる
#   RDF: (調理器, て誤る, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器で料理を一緒に作る
#   RDF: (調理器, 作る, 行為)
#   RDF: (料理, 作る, 行為)
#   RDF: (一緒, 作る, 行為)
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, 料理, 使用)
#   RDF: (自動, 一緒, 使用)
#   RDF: (調理器, 料理, 使用)
#   RDF: (調理器, 一緒, 使用)
#   RDF: (料理, 一緒, 使用)
# Item: 自動調理器, Action: 自動調理器を貸す
#   RDF: (調理器, 貸す, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を借りる
#   RDF: (調理器, 借りる, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を共有する
#   RDF: (調理器, 共有する, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器料理を楽しむ
#   RDF: (料理, 楽しむ, 行為)
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, 料理, 使用)
#   RDF: (調理器, 料理, 使用)
# Item: 自動調理器, Action: 自動調理器のレシピを教える
#   RDF: (レシピ, 教える, 行為)
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, レシピ, 使用)
#   RDF: (調理器, レシピ, 使用)
# Item: 自動調理器, Action: 自動調理器の感想を言う
#   RDF: (感想, 言う, 行為)
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, 感想, 使用)
#   RDF: (調理器, 感想, 使用)
# Item: 自動調理器, Action: 自動調理器を返す
#   RDF: (調理器, 返す, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を贈る
#   RDF: (調理器, 贈る, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を見せる
#   RDF: (調理器, 見せる, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を取り合う
#   RDF: (調理器, 取り合う, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器について話す
#   RDF: (調理器, 話す, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を交換する
#   RDF: (調理器, 交換する, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を紹介する
#   RDF: (調理器, 紹介する, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を一緒に使う
#   RDF: (調理器, 使う, 行為)
#   RDF: (一緒, 使う, 行為)
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, 一緒, 使用)
#   RDF: (調理器, 一緒, 使用)
# Item: 自動調理器, Action: 自動調理器を探し合う
#   RDF: (調理器, 探す, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を手渡す
#   RDF: (調理器, 手渡す, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を洗い合う
#   RDF: (調理器, 洗い合う, 行為)
#   RDF: (自動, 調理器, 使用)
# Item: 自動調理器, Action: 自動調理器を使って料理を教える
#   RDF: (調理器, て使う, 行為)
#   RDF: (料理, 教える, 行為)
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, 料理, 使用)
#   RDF: (調理器, 料理, 使用)
# Item: 自動調理器, Action: 自動調理器の使い方を説明する
#   RDF: (使い方, 説明する, 行為)
#   RDF: (自動, 調理器, 使用)
#   RDF: (自動, 使い方, 使用)
#   RDF: (調理器, 使い方, 使用)
# Item: 観光本, Action: 観光本を手に取る
#   RDF: (本, 取る, 行為)
#   RDF: (手, 取る, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, 手, 使用)
#   RDF: (本, 手, 使用)
# Item: 観光本, Action: 目次を確認する
#   RDF: (目次, 確認する, 行為)
# Item: 観光本, Action: 目的地を探す
#   RDF: (目的地, 探す, 行為)
# Item: 観光本, Action: ページをめくる
# Item: 観光本, Action: 地図を確認する
#   RDF: (地図, 確認する, 行為)
# Item: 観光本, Action: 写真を見る
#   RDF: (写真, 見る, 行為)
# Item: 観光本, Action: おすすめスポットを読む
#   RDF: (スポット, 読む, 行為)
#   RDF: (おすすめ, スポット, 使用)
# Item: 観光本, Action: 観光ルートを考える
#   RDF: (ルート, 考える, 行為)
#   RDF: (観光, ルート, 使用)
# Item: 観光本, Action: メモを取る
#   RDF: (メモ, 取る, 行為)
# Item: 観光本, Action: 付箋を貼る
#   RDF: (付箋, 貼る, 行為)
# Item: 観光本, Action: ページを折る
#   RDF: (ページ, 折る, 行為)
# Item: 観光本, Action: しおりを挟む
#   RDF: (しおり, 挟む, 行為)
# Item: 観光本, Action: 旅行計画を立てる
#   RDF: (計画, 立てる, 行為)
#   RDF: (旅行, 計画, 使用)
# Item: 観光本, Action: 観光地の情報を読む
#   RDF: (情報, 読む, 行為)
#   RDF: (観光地, 情報, 使用)
# Item: 観光本, Action: 持ち物リストを作る
#   RDF: (リスト, 作る, 行為)
#   RDF: (持ち物, リスト, 使用)
# Item: 観光本, Action: 読み終わったページを閉じる
#   RDF: (ページ, 閉じる, 行為)
# Item: 観光本, Action: 本棚に戻す
#   RDF: (本棚, 戻す, 行為)
# Item: 観光本, Action: 友人に見せる
#   RDF: (友人, 見せる, 行為)
# Item: 観光本, Action: レビューを読む
#   RDF: (レビュー, 読む, 行為)
# Item: 観光本, Action: 本を持ち運ぶ
#   RDF: (本, 持ち運ぶ, 使用)
# Item: 観光本, Action: ノートにメモを取る
#   RDF: (ノート, 取る, 行為)
#   RDF: (メモ, 取る, 行為)
#   RDF: (ノート, メモ, 使用)
# Item: 観光本, Action: ペンを使ってマークする
#   RDF: (ペン, て使う, 行為)
# Item: 観光本, Action: スマホで写真を撮る
#   RDF: (スマホ, 撮る, 行為)
#   RDF: (写真, 撮る, 行為)
#   RDF: (スマホ, 写真, 使用)
# Item: 観光本, Action: コンパスで方角を確認する
#   RDF: (コンパス, 確認する, 行為)
#   RDF: (方角, 確認する, 行為)
#   RDF: (コンパス, 方角, 使用)
# Item: 観光本, Action: カメラで撮影する
#   RDF: (カメラ, 撮影する, 行為)
# Item: 観光本, Action: 地図をコピーする
#   RDF: (地図, コピーする, 行為)
# Item: 観光本, Action: 旅行ガイドアプリを使う
#   RDF: (アプリ, 使う, 行為)
#   RDF: (旅行, ガイド, 使用)
#   RDF: (旅行, アプリ, 使用)
#   RDF: (ガイド, アプリ, 使用)
# Item: 観光本, Action: ブックカバーをかける
#   RDF: (ブックカバー, かける, 行為)
# Item: 観光本, Action: 旅行バッグに入れる
#   RDF: (バッグ, 入れる, 行為)
#   RDF: (旅行, バッグ, 使用)
# Item: 観光本, Action: スマホで地図を見る
#   RDF: (スマホ, 見る, 行為)
#   RDF: (地図, 見る, 行為)
#   RDF: (スマホ, 地図, 使用)
# Item: 観光本, Action: 辞書で調べる
#   RDF: (辞書, 調べる, 行為)
# Item: 観光本, Action: PCで情報を検索する
#   RDF: (PC, 検索する, 行為)
#   RDF: (情報, 検索する, 行為)
#   RDF: (PC, 情報, 使用)
# Item: 観光本, Action: ガイドブックを比較する
#   RDF: (ガイドブック, 比較する, 行為)
# Item: 観光本, Action: タブレットで電子版を読む
#   RDF: (タブレット, 読む, 行為)
#   RDF: (版, 読む, 行為)
#   RDF: (タブレット, 電子, 使用)
#   RDF: (タブレット, 版, 使用)
#   RDF: (電子, 版, 使用)
# Item: 観光本, Action: ハイライトを引く
#   RDF: (ハイライト, 引く, 行為)
# Item: 観光本, Action: 雑誌と一緒に読む
#   RDF: (一緒, 読む, 行為)
#   RDF: (雑誌, 一緒, 使用)
# Item: 観光本, Action: 航空券と一緒に準備する
#   RDF: (一緒, 準備する, 行為)
#   RDF: (航空券, 一緒, 使用)
# Item: 観光本, Action: 旅行保険の情報を確認する
#   RDF: (情報, 確認する, 行為)
#   RDF: (旅行, 保険, 使用)
#   RDF: (旅行, 情報, 使用)
#   RDF: (保険, 情報, 使用)
# Item: 観光本, Action: ホテル予約と合わせる
# Item: 観光本, Action: カフェで読みながら計画を立てる
#   RDF: (カフェ, ながら読む, 行為)
#   RDF: (計画, 立てる, 行為)
#   RDF: (カフェ, 計画, 使用)
# Item: 観光本, Action: 観光本で紙飛行機を作る
#   RDF: (本, 作る, 行為)
#   RDF: (飛行機, 作る, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, 紙, 使用)
#   RDF: (観光, 飛行機, 使用)
#   RDF: (本, 紙, 使用)
#   RDF: (本, 飛行機, 使用)
#   RDF: (紙, 飛行機, 使用)
# Item: 観光本, Action: 観光本でドミノをする
#   RDF: (本, する, 行為)
#   RDF: (ドミノ, する, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, ドミノ, 使用)
#   RDF: (本, ドミノ, 使用)
# Item: 観光本, Action: 観光本を積み上げてタワーを作る
#   RDF: (本, て積み上げる, 行為)
#   RDF: (タワー, 作る, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, タワー, 使用)
#   RDF: (本, タワー, 使用)
# Item: 観光本, Action: 観光本を塗り絵にする
#   RDF: (本, する, 行為)
#   RDF: (塗り絵, する, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, 塗り絵, 使用)
#   RDF: (本, 塗り絵, 使用)
# Item: 観光本, Action: 観光本の写真を切り抜く
#   RDF: (写真, 切り抜く, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, 写真, 使用)
#   RDF: (本, 写真, 使用)
# Item: 観光本, Action: 観光本で折り紙をする
#   RDF: (本, する, 行為)
#   RDF: (折り紙, する, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, 折り紙, 使用)
#   RDF: (本, 折り紙, 使用)
# Item: 観光本, Action: 観光本を使って宝探しゲームをする
#   RDF: (本, て使う, 行為)
#   RDF: (ゲーム, する, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, 宝探し, 使用)
#   RDF: (観光, ゲーム, 使用)
#   RDF: (本, 宝探し, 使用)
#   RDF: (本, ゲーム, 使用)
#   RDF: (宝探し, ゲーム, 使用)
# Item: 観光本, Action: 観光本でかくれんぼをする
#   RDF: (本, する, 行為)
#   RDF: (かくれんぼ, する, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, かくれんぼ, 使用)
#   RDF: (本, かくれんぼ, 使用)
# Item: 観光本, Action: 観光本をマントにする
#   RDF: (本, する, 行為)
#   RDF: (マント, する, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, マント, 使用)
#   RDF: (本, マント, 使用)
# Item: 観光本, Action: 観光本を仮面にする
#   RDF: (本, する, 行為)
#   RDF: (仮面, する, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, 仮面, 使用)
#   RDF: (本, 仮面, 使用)
# Item: 観光本, Action: 観光本を使ってパズルを作る
#   RDF: (本, て使う, 行為)
#   RDF: (パズル, 作る, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, パズル, 使用)
#   RDF: (本, パズル, 使用)
# Item: 観光本, Action: 観光本で風を送る
#   RDF: (本, 送る, 行為)
#   RDF: (風, 送る, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, 風, 使用)
#   RDF: (本, 風, 使用)
# Item: 観光本, Action: 観光本を丸めて棒にする
#   RDF: (本, て丸める, 行為)
#   RDF: (棒, する, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, 棒, 使用)
#   RDF: (本, 棒, 使用)
# Item: 観光本, Action: 観光本を使って紙相撲をする
#   RDF: (本, て使う, 行為)
#   RDF: (紙相撲, する, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, 紙相撲, 使用)
#   RDF: (本, 紙相撲, 使用)
# Item: 観光本, Action: 観光本でトンネルを作る
#   RDF: (本, 作る, 行為)
#   RDF: (トンネル, 作る, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, トンネル, 使用)
#   RDF: (本, トンネル, 使用)
# Item: 観光本, Action: 観光本でおもちゃを運ぶ
#   RDF: (本, 運ぶ, 行為)
#   RDF: (おもちゃ, 運ぶ, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, おもちゃ, 使用)
#   RDF: (本, おもちゃ, 使用)
# Item: 観光本, Action: 観光本を積み上げて競う
#   RDF: (本, て積み上げる, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: 観光本を使って迷路を作る
#   RDF: (本, て使う, 行為)
#   RDF: (迷路, 作る, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, 迷路, 使用)
#   RDF: (本, 迷路, 使用)
# Item: 観光本, Action: 観光本でバランスゲームをする
#   RDF: (本, する, 行為)
#   RDF: (ゲーム, する, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, ゲーム, 使用)
#   RDF: (本, ゲーム, 使用)
# Item: 観光本, Action: 観光本を使って壁飾りを作る
#   RDF: (本, て使う, 行為)
#   RDF: (壁飾り, 作る, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, 壁飾り, 使用)
#   RDF: (本, 壁飾り, 使用)
# Item: 観光本, Action: ページをめくる
# Item: 観光本, Action: 指をなめる
#   RDF: (指, なめる, 行為)
# Item: 観光本, Action: 観光本を持ち上げる
#   RDF: (本, 持ち上げる, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: 観光本を傾ける
#   RDF: (本, 傾ける, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: ページの角を折る
#   RDF: (角, 折る, 行為)
#   RDF: (ページ, 角, 使用)
# Item: 観光本, Action: 観光本を閉じる
#   RDF: (本, 閉じる, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: 読む速度を変える
#   RDF: (速度, 変える, 行為)
# Item: 観光本, Action: 目をこする
#   RDF: (目, こする, 行為)
# Item: 観光本, Action: 読んでいる場所を見失う
#   RDF: (場所, 見失う, 行為)
# Item: 観光本, Action: しおりを挟む
#   RDF: (しおり, 挟む, 行為)
# Item: 観光本, Action: 観光本を机に置く
#   RDF: (本, 置く, 行為)
#   RDF: (机, 置く, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, 机, 使用)
#   RDF: (本, 机, 使用)
# Item: 観光本, Action: 観光本を膝の上に置く
#   RDF: (本, 置く, 行為)
#   RDF: (上, 置く, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, 膝, 使用)
#   RDF: (観光, 上, 使用)
#   RDF: (本, 膝, 使用)
#   RDF: (本, 上, 使用)
#   RDF: (膝, 上, 使用)
# Item: 観光本, Action: 観光本を開いたまま置く
#   RDF: (本, 開くた, 行為)
#   RDF: (まま, 置く, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, まま, 使用)
#   RDF: (本, まま, 使用)
# Item: 観光本, Action: ページを撫でる
#   RDF: (ページ, 撫でる, 行為)
# Item: 観光本, Action: 観光本を上下逆にする
#   RDF: (本, する, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, 上下, 使用)
#   RDF: (本, 上下, 使用)
# Item: 観光本, Action: 観光本を片手で持つ
#   RDF: (本, 持つ, 行為)
#   RDF: (片手, 持つ, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, 片手, 使用)
#   RDF: (本, 片手, 使用)
# Item: 観光本, Action: 頭をかく
# Item: 観光本, Action: 観光本の匂いを嗅ぐ
#   RDF: (匂い, 嗅ぐ, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, 匂い, 使用)
#   RDF: (本, 匂い, 使用)
# Item: 観光本, Action: 観光本を指で叩く
#   RDF: (本, 叩く, 行為)
#   RDF: (指, 叩く, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, 指, 使用)
#   RDF: (本, 指, 使用)
# Item: 観光本, Action: 観光本を手元に引き寄せる
#   RDF: (本, 引き寄せる, 行為)
#   RDF: (手元, 引き寄せる, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, 手元, 使用)
#   RDF: (本, 手元, 使用)
# Item: 観光本, Action: 観光本を落とす
#   RDF: (本, 落とす, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: ページを破る
#   RDF: (ページ, 破る, 行為)
# Item: 観光本, Action: しおりをなくす
#   RDF: (しおり, なくす, 行為)
# Item: 観光本, Action: 観光本を濡らす
#   RDF: (本, 濡らす, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: 観光本を汚す
#   RDF: (本, 汚す, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: ページを折る
#   RDF: (ページ, 折る, 行為)
# Item: 観光本, Action: ページが引っかかる
# Item: 観光本, Action: 観光本を破る
#   RDF: (本, 破る, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: 誤って観光本を閉じる
#   RDF: (本, 閉じる, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: ページを抜かす
#   RDF: (ページ, 抜かす, 行為)
# Item: 観光本, Action: 観光本が開かない
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: 指を切る
#   RDF: (指, 切る, 行為)
# Item: 観光本, Action: 観光本を忘れる
#   RDF: (本, 忘れる, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: 誤って線を引く
#   RDF: (線, 引く, 行為)
# Item: 観光本, Action: 付箋をなくす
#   RDF: (付箋, なくす, 行為)
# Item: 観光本, Action: 観光本を踏む
#   RDF: (本, 踏む, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: 観光本を逆さまに読む
#   RDF: (本, 読む, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: 観光本を紛失する
#   RDF: (本, 紛失する, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: 観光本のカバーを破る
#   RDF: (カバー, 破る, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, カバー, 使用)
#   RDF: (本, カバー, 使用)
# Item: 観光本, Action: 観光本が見つからない
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: 観光本を貸す
#   RDF: (本, 貸す, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: 観光本を借りる
#   RDF: (本, 借りる, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: 観光本を共有する
#   RDF: (本, 共有する, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: 観光本について話す
#   RDF: (本, 話す, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: 観光本を推薦する
#   RDF: (本, 推薦する, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: 観光本を贈る
#   RDF: (本, 贈る, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: 観光本を返す
#   RDF: (本, 返す, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: 一緒に読む
#   RDF: (一緒, 読む, 行為)
# Item: 観光本, Action: 旅行計画を一緒に立てる
#   RDF: (計画, 立てる, 行為)
#   RDF: (一緒, 立てる, 行為)
#   RDF: (旅行, 計画, 使用)
#   RDF: (旅行, 一緒, 使用)
#   RDF: (計画, 一緒, 使用)
# Item: 観光本, Action: 感想を交換する
#   RDF: (感想, 交換する, 行為)
# Item: 観光本, Action: 観光本を見せる
#   RDF: (本, 見せる, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: 観光本を取り合う
#   RDF: (本, 取り合う, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: 観光本について議論する
#   RDF: (本, 議論する, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: 観光本を読む時間を作る
#   RDF: (本, 読む, 行為)
#   RDF: (時間, 作る, 行為)
#   RDF: (観光, 本, 使用)
#   RDF: (観光, 時間, 使用)
#   RDF: (本, 時間, 使用)
# Item: 観光本, Action: 観光本をプレゼントする
#   RDF: (本, プレゼントする, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: 観光本を交換する
#   RDF: (本, 交換する, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: 観光本を置き忘れる
#   RDF: (本, 置く, 行為)
#   RDF: (観光, 本, 使用)
# Item: 観光本, Action: 観光本を探し合う
# ...
# Item: ストーブ, Action: カーペットを敷く
#   RDF: (カーペット, 敷く, 行為)
# Item: ストーブ, Action: 温度センサーを使う
#   RDF: (センサー, 使う, 行為)
#   RDF: (温度, センサー, 使用)
# Item: ストーブ, Action: スマートフォンアプリを使う
#   RDF: (アプリ, 使う, 行為)
#   RDF: (スマートフォン, アプリ, 使用)
# Item: ストーブ, Action: センサーライトを使う
#   RDF: (ライト, 使う, 行為)
#   RDF: (センサー, ライト, 使用)
# Item: ストーブ, Action: 空気清浄機を使う
#   RDF: (空気清浄機, 使う, 行為)
# Item: ストーブ, Action: ストーブでマシュマロを焼く
#   RDF: (ストーブ, 焼く, 行為)
#   RDF: (マシュマロ, 焼く, 行為)
#   RDF: (ストーブ, マシュマロ, 使用)
# Item: ストーブ, Action: ストーブでパンを焼く
#   RDF: (ストーブ, 焼く, 行為)
#   RDF: (パン, 焼く, 行為)
#   RDF: (ストーブ, パン, 使用)
# Item: ストーブ, Action: ストーブでポップコーンを作る
#   RDF: (ストーブ, 作る, 行為)
#   RDF: (ポップコーン, 作る, 行為)
#   RDF: (ストーブ, ポップコーン, 使用)
# Item: ストーブ, Action: ストーブで手を温める
#   RDF: (ストーブ, 温める, 行為)
#   RDF: (手, 温める, 行為)
#   RDF: (ストーブ, 手, 使用)
# Item: ストーブ, Action: ストーブでドライフルーツを作る
#   RDF: (ストーブ, 作る, 行為)
#   RDF: (ドライフルーツ, 作る, 行為)
#   RDF: (ストーブ, ドライフルーツ, 使用)
# Item: ストーブ, Action: ストーブで焼き芋を作る
#   RDF: (ストーブ, 作る, 行為)
#   RDF: (焼き芋, 作る, 行為)
#   RDF: (ストーブ, 焼き芋, 使用)
# Item: ストーブ, Action: ストーブでコーヒーを温める
#   RDF: (ストーブ, 温める, 行為)
#   RDF: (コーヒー, 温める, 行為)
#   RDF: (ストーブ, コーヒー, 使用)
# Item: ストーブ, Action: ストーブで紅茶を温める
#   RDF: (ストーブ, 温める, 行為)
#   RDF: (紅茶, 温める, 行為)
#   RDF: (ストーブ, 紅茶, 使用)
# Item: ストーブ, Action: ストーブでチーズを溶かす
#   RDF: (ストーブ, 溶かす, 行為)
#   RDF: (チーズ, 溶かす, 行為)
#   RDF: (ストーブ, チーズ, 使用)
# Item: ストーブ, Action: ストーブでスープを温める
#   RDF: (ストーブ, 温める, 行為)
#   RDF: (スープ, 温める, 行為)
#   RDF: (ストーブ, スープ, 使用)
# Item: ストーブ, Action: ストーブでミルクを温める
#   RDF: (ストーブ, 温める, 行為)
#   RDF: (ミルク, 温める, 行為)
#   RDF: (ストーブ, ミルク, 使用)
# Item: ストーブ, Action: ストーブでハーブティーを作る
#   RDF: (ストーブ, 作る, 行為)
#   RDF: (ハーブティー, 作る, 行為)
#   RDF: (ストーブ, ハーブティー, 使用)
# Item: ストーブ, Action: ストーブで燻製を作る
#   RDF: (ストーブ, 作る, 行為)
#   RDF: (燻製, 作る, 行為)
#   RDF: (ストーブ, 燻製, 使用)
# Item: ストーブ, Action: ストーブで乾燥フルーツを作る
#   RDF: (ストーブ, 作る, 行為)
#   RDF: (フルーツ, 作る, 行為)
#   RDF: (ストーブ, 乾燥, 使用)
#   RDF: (ストーブ, フルーツ, 使用)
#   RDF: (乾燥, フルーツ, 使用)
# Item: ストーブ, Action: ストーブでグリルをする
#   RDF: (ストーブ, する, 行為)
#   RDF: (グリル, する, 行為)
#   RDF: (ストーブ, グリル, 使用)
# Item: ストーブ, Action: ストーブでクッキーを焼く
#   RDF: (ストーブ, 焼く, 行為)
#   RDF: (クッキー, 焼く, 行為)
#   RDF: (ストーブ, クッキー, 使用)
# Item: ストーブ, Action: ストーブでピザを温める
#   RDF: (ストーブ, 温める, 行為)
#   RDF: (ピザ, 温める, 行為)
#   RDF: (ストーブ, ピザ, 使用)
# Item: ストーブ, Action: ストーブでカレーを温める
#   RDF: (ストーブ, 温める, 行為)
#   RDF: (カレー, 温める, 行為)
#   RDF: (ストーブ, カレー, 使用)
# Item: ストーブ, Action: ストーブでシチューを温める
#   RDF: (ストーブ, 温める, 行為)
#   RDF: (シチュー, 温める, 行為)
#   RDF: (ストーブ, シチュー, 使用)
# Item: ストーブ, Action: ストーブで温泉卵を作る
#   RDF: (ストーブ, 作る, 行為)
#   RDF: (卵, 作る, 行為)
#   RDF: (ストーブ, 温泉, 使用)
#   RDF: (ストーブ, 卵, 使用)
#   RDF: (温泉, 卵, 使用)
# Item: ストーブ, Action: ストーブの電源を入れる
#   RDF: (電源, 入れる, 行為)
#   RDF: (ストーブ, 電源, 使用)
# Item: ストーブ, Action: ストーブの燃料を確認する
#   RDF: (燃料, 確認する, 行為)
#   RDF: (ストーブ, 燃料, 使用)
# Item: ストーブ, Action: ストーブを点火する
#   RDF: (ストーブ, 点火する, 行為)
# Item: ストーブ, Action: ストーブの温度を設定する
#   RDF: (温度, 設定する, 行為)
#   RDF: (ストーブ, 温度, 使用)
# Item: ストーブ, Action: ストーブのファンを調整する
#   RDF: (ファン, 調整する, 行為)
#   RDF: (ストーブ, ファン, 使用)
# Item: ストーブ, Action: ストーブの温度を確認する
#   RDF: (温度, 確認する, 行為)
#   RDF: (ストーブ, 温度, 使用)
# Item: ストーブ, Action: ストーブの燃料を補充する
#   RDF: (燃料, 補充する, 行為)
#   RDF: (ストーブ, 燃料, 使用)
# Item: ストーブ, Action: ストーブを消火する
#   RDF: (ストーブ, 消火する, 行為)
# Item: ストーブ, Action: ストーブの掃除をする
#   RDF: (掃除, する, 行為)
#   RDF: (ストーブ, 掃除, 使用)
# Item: ストーブ, Action: ストーブのフィルターを掃除する
#   RDF: (フィルター, 掃除する, 行為)
#   RDF: (ストーブ, フィルター, 使用)
# Item: ストーブ, Action: ストーブの位置を調整する
#   RDF: (位置, 調整する, 行為)
#   RDF: (ストーブ, 位置, 使用)
# Item: ストーブ, Action: ストーブの安全装置を確認する
#   RDF: (装置, 確認する, 行為)
#   RDF: (ストーブ, 安全, 使用)
#   RDF: (ストーブ, 装置, 使用)
#   RDF: (安全, 装置, 使用)
# Item: ストーブ, Action: ストーブの電源を切る
#   RDF: (電源, 切る, 行為)
#   RDF: (ストーブ, 電源, 使用)
# Item: ストーブ, Action: ストーブを移動する
#   RDF: (ストーブ, 移動する, 行為)
# Item: ストーブ, Action: ストーブの換気を確認する
#   RDF: (換気, 確認する, 行為)
#   RDF: (ストーブ, 換気, 使用)
# Item: ストーブ, Action: ストーブの異音を確認する
#   RDF: (異音, 確認する, 行為)
#   RDF: (ストーブ, 異音, 使用)
# Item: ストーブ, Action: ストーブの煙突を掃除する
#   RDF: (煙突, 掃除する, 行為)
#   RDF: (ストーブ, 煙突, 使用)
# Item: ストーブ, Action: ストーブの設定を変更する
#   RDF: (設定, 変更する, 行為)
#   RDF: (ストーブ, 設定, 使用)
# Item: ストーブ, Action: ストーブのメンテナンスをする
#   RDF: (メンテナンス, する, 行為)
#   RDF: (ストーブ, メンテナンス, 使用)
# Item: ストーブ, Action: ストーブの取扱説明書を読む
#   RDF: (取扱説明書, 読む, 行為)
#   RDF: (ストーブ, 取扱説明書, 使用)
# Item: ストーブ, Action: ストーブの燃料が切れる
#   RDF: (ストーブ, 燃料, 使用)
# Item: ストーブ, Action: ストーブが点火しない
# Item: ストーブ, Action: ストーブが過熱する
# Item: ストーブ, Action: ストーブの火力が弱い
#   RDF: (ストーブ, 火力, 使用)
# Item: ストーブ, Action: ストーブのフィルターが詰まる
#   RDF: (ストーブ, フィルター, 使用)
# Item: ストーブ, Action: ストーブの煙突が詰まる
#   RDF: (ストーブ, 煙突, 使用)
# Item: ストーブ, Action: ストーブの異音がする
#   RDF: (ストーブ, 異音, 使用)
# Item: ストーブ, Action: ストーブの火が消える
#   RDF: (ストーブ, 火, 使用)
# Item: ストーブ, Action: ストーブが倒れる
# Item: ストーブ, Action: ストーブが煙を出す
#   RDF: (煙, 出す, 行為)
#   RDF: (ストーブ, 煙, 使用)
# Item: ストーブ, Action: ストーブの温度が上がらない
#   RDF: (ストーブ, 温度, 使用)
# Item: ストーブ, Action: ストーブが燃えすぎる
# Item: ストーブ, Action: ストーブが壊れる
# Item: ストーブ, Action: ストーブの電源が入らない
#   RDF: (ストーブ, 電源, 使用)
# Item: ストーブ, Action: ストーブの温度設定が狂う
#   RDF: (ストーブ, 温度, 使用)
#   RDF: (ストーブ, 設定, 使用)
#   RDF: (温度, 設定, 使用)
# Item: ストーブ, Action: ストーブのファンが回らない
#   RDF: (ストーブ, ファン, 使用)
# Item: ストーブ, Action: ストーブが燃料を漏らす
#   RDF: (燃料, 漏らす, 行為)
#   RDF: (ストーブ, 燃料, 使用)
# Item: ストーブ, Action: ストーブが燃え尽きる
# Item: ストーブ, Action: ストーブが過熱して火災になる
#   RDF: (火災, なる, 行為)
#   RDF: (ストーブ, 火災, 使用)
# Item: ストーブ, Action: ストーブの燃料補充が難しい
#   RDF: (ストーブ, 燃料, 使用)
#   RDF: (ストーブ, 補充, 使用)
#   RDF: (燃料, 補充, 使用)
# Item: ストーブ, Action: ストーブの使い方を教える
#   RDF: (使い方, 教える, 行為)
#   RDF: (ストーブ, 使い方, 使用)
# Item: ストーブ, Action: 一緒にストーブを使う
#   RDF: (一緒, 使う, 行為)
#   RDF: (ストーブ, 使う, 行為)
#   RDF: (一緒, ストーブ, 使用)
# Item: ストーブ, Action: ストーブの燃料を補充する手伝いをする
#   RDF: (燃料, 補充する, 行為)
#   RDF: (手伝い, する, 行為)
#   RDF: (ストーブ, 燃料, 使用)
#   RDF: (ストーブ, 手伝い, 使用)
#   RDF: (燃料, 手伝い, 使用)
# Item: ストーブ, Action: ストーブの掃除を手伝う
#   RDF: (掃除, 手伝う, 行為)
#   RDF: (ストーブ, 掃除, 使用)
# Item: ストーブ, Action: ストーブのメンテナンスを手伝う
#   RDF: (メンテナンス, 手伝う, 行為)
#   RDF: (ストーブ, メンテナンス, 使用)
# Item: ストーブ, Action: ストーブの購入を相談する
#   RDF: (購入, 相談する, 行為)
#   RDF: (ストーブ, 購入, 使用)
# Item: ストーブ, Action: ストーブの特徴を話す
#   RDF: (特徴, 話す, 行為)
#   RDF: (ストーブ, 特徴, 使用)
# Item: ストーブ, Action: ストーブの魅力を伝える
#   RDF: (魅力, 伝える, 行為)
#   RDF: (ストーブ, 魅力, 使用)
# Item: ストーブ, Action: ストーブの修理を手伝う
#   RDF: (修理, 手伝う, 行為)
#   RDF: (ストーブ, 修理, 使用)
# Item: ストーブ, Action: ストーブの収納を手伝う
#   RDF: (収納, 手伝う, 行為)
#   RDF: (ストーブ, 収納, 使用)
# Item: ストーブ, Action: ストーブの歴史を調べる
#   RDF: (歴史, 調べる, 行為)
#   RDF: (ストーブ, 歴史, 使用)
# Item: ストーブ, Action: ストーブの展示を手伝う
#   RDF: (展示, 手伝う, 行為)
#   RDF: (ストーブ, 展示, 使用)
# Item: ストーブ, Action: ストーブの情報を交換する
#   RDF: (情報, 交換する, 行為)
#   RDF: (ストーブ, 情報, 使用)
# Item: ストーブ, Action: ストーブのブランドを比べる
#   RDF: (ブランド, 比べる, 行為)
#   RDF: (ストーブ, ブランド, 使用)
# Item: ストーブ, Action: ストーブの機能を説明する
#   RDF: (機能, 説明する, 行為)
#   RDF: (ストーブ, 機能, 使用)
# Item: ストーブ, Action: ストーブの使い心地を話す
#   RDF: (使い心地, 話す, 行為)
#   RDF: (ストーブ, 使い心地, 使用)
# Item: ストーブ, Action: ストーブのおすすめを紹介する
#   RDF: (おすすめ, 紹介する, 行為)
#   RDF: (ストーブ, おすすめ, 使用)
# Item: ストーブ, Action: ストーブの燃料を買いに行く
#   RDF: (燃料, 買う, 行為)
#   RDF: (ストーブ, 燃料, 使用)
# Item: ストーブ, Action: ストーブの燃料をシェアする
#   RDF: (燃料, シェアする, 行為)
#   RDF: (ストーブ, 燃料, 使用)
# Item: ストーブ, Action: ストーブの火を囲んで語り合う
#   RDF: (火, で囲む, 行為)
#   RDF: (ストーブ, 火, 使用)
# Item: 暖房, Action: 暖房の電源を入れる
#   RDF: (電源, 入れる, 行為)
#   RDF: (暖房, 電源, 使用)
# Item: 暖房, Action: 暖房の温度を設定する
#   RDF: (温度, 設定する, 行為)
#   RDF: (暖房, 温度, 使用)
# Item: 暖房, Action: 暖房の風量を調整する
#   RDF: (風量, 調整する, 行為)
#   RDF: (暖房, 風量, 使用)
# Item: 暖房, Action: 暖房のタイマーを設定する
#   RDF: (タイマー, 設定する, 行為)
#   RDF: (暖房, タイマー, 使用)
# Item: 暖房, Action: 暖房の運転モードを選ぶ
#   RDF: (モード, 選ぶ, 行為)
#   RDF: (暖房, 運転, 使用)
#   RDF: (暖房, モード, 使用)
#   RDF: (運転, モード, 使用)
# Item: 暖房, Action: 暖房のフィルターを確認する
#   RDF: (フィルター, 確認する, 行為)
#   RDF: (暖房, フィルター, 使用)
# Item: 暖房, Action: 暖房のフィルターを掃除する
#   RDF: (フィルター, 掃除する, 行為)
#   RDF: (暖房, フィルター, 使用)
# Item: 暖房, Action: 暖房の電源を切る
#   RDF: (電源, 切る, 行為)
#   RDF: (暖房, 電源, 使用)
# Item: 暖房, Action: 暖房の位置を調整する
#   RDF: (位置, 調整する, 行為)
#   RDF: (暖房, 位置, 使用)
# Item: 暖房, Action: 暖房のリモコンを使う
#   RDF: (リモコン, 使う, 行為)
#   RDF: (暖房, リモコン, 使用)
# Item: 暖房, Action: 暖房の操作パネルを確認する
#   RDF: (パネル, 確認する, 行為)
#   RDF: (暖房, 操作, 使用)
#   RDF: (暖房, パネル, 使用)
#   RDF: (操作, パネル, 使用)
# Item: 暖房, Action: 暖房の換気を確認する
#   RDF: (換気, 確認する, 行為)
#   RDF: (暖房, 換気, 使用)
# Item: 暖房, Action: 暖房の音を確認する
#   RDF: (音, 確認する, 行為)
#   RDF: (暖房, 音, 使用)
# Item: 暖房, Action: 暖房の使用説明書を読む
#   RDF: (使用説明書, 読む, 行為)
#   RDF: (暖房, 使用説明書, 使用)
# Item: 暖房, Action: 暖房の点検をする
#   RDF: (点検, する, 行為)
#   RDF: (暖房, 点検, 使用)
# Item: 暖房, Action: 暖房の消耗品を交換する
#   RDF: (消耗品, 交換する, 行為)
#   RDF: (暖房, 消耗品, 使用)
# Item: 暖房, Action: 暖房のエアフィルターを交換する
#   RDF: (エアフィルター, 交換する, 行為)
#   RDF: (暖房, エアフィルター, 使用)
# Item: 暖房, Action: 暖房の定期メンテナンスをする
#   RDF: (メンテナンス, する, 行為)
#   RDF: (暖房, 定期, 使用)
#   RDF: (暖房, メンテナンス, 使用)
#   RDF: (定期, メンテナンス, 使用)
# Item: 暖房, Action: 暖房の異常を確認する
#   RDF: (異常, 確認する, 行為)
#   RDF: (暖房, 異常, 使用)
# Item: 暖房, Action: 暖房の安全装置を確認する
#   RDF: (装置, 確認する, 行為)
#   RDF: (暖房, 安全, 使用)
#   RDF: (暖房, 装置, 使用)
#   RDF: (安全, 装置, 使用)
# Item: 暖房, Action: リモコンを使う
#   RDF: (リモコン, 使う, 行為)
# Item: 暖房, Action: 温度計を使う
#   RDF: (温度計, 使う, 行為)
# Item: 暖房, Action: 加湿器を使う
#   RDF: (加湿器, 使う, 行為)
# Item: 暖房, Action: エアフィルターを使う
#   RDF: (エアフィルター, 使う, 行為)
# Item: 暖房, Action: 電源コードを使う
#   RDF: (コード, 使う, 行為)
#   RDF: (電源, コード, 使用)
# Item: 暖房, Action: 延長コードを使う
#   RDF: (コード, 使う, 行為)
#   RDF: (延長, コード, 使用)
# Item: 暖房, Action: フィルタークリーナーを使う
#   RDF: (クリーナー, 使う, 行為)
#   RDF: (フィルター, クリーナー, 使用)
# Item: 暖房, Action: 温度センサーを使う
#   RDF: (センサー, 使う, 行為)
#   RDF: (温度, センサー, 使用)
# Item: 暖房, Action: 換気扇を使う
#   RDF: (換気扇, 使う, 行為)
# Item: 暖房, Action: 空気清浄機を使う
#   RDF: (空気清浄機, 使う, 行為)
# Item: 暖房, Action: サーキュレーターを使う
#   RDF: (サーキュレーター, 使う, 行為)
# Item: 暖房, Action: スマートフォンアプリを使う
#   RDF: (アプリ, 使う, 行為)
#   RDF: (スマートフォン, アプリ, 使用)
# Item: 暖房, Action: 電源タップを使う
#   RDF: (電源タップ, 使う, 行為)
# Item: 暖房, Action: タイマーを使う
#   RDF: (タイマー, 使う, 行為)
# Item: 暖房, Action: 電圧変換器を使う
#   RDF: (器, 使う, 行為)
#   RDF: (電圧, 変換, 使用)
#   RDF: (電圧, 器, 使用)
#   RDF: (変換, 器, 使用)
# Item: 暖房, Action: 電源アダプターを使う
#   RDF: (アダプター, 使う, 行為)
#   RDF: (電源, アダプター, 使用)
# Item: 暖房, Action: 防寒着を使う
#   RDF: (防寒着, 使う, 行為)
# Item: 暖房, Action: 温風ファンを使う
#   RDF: (ファン, 使う, 行為)
#   RDF: (温風, ファン, 使用)
# Item: 暖房, Action: 断熱カーテンを使う
#   RDF: (カーテン, 使う, 行為)
#   RDF: (断熱, カーテン, 使用)
# Item: 暖房, Action: 窓のシーリングを確認する
#   RDF: (シーリング, 確認する, 行為)
#   RDF: (窓, シーリング, 使用)
# Item: 暖房, Action: 暖房でマシュマロを温める
#   RDF: (暖房, 温める, 行為)
#   RDF: (マシュマロ, 温める, 行為)
#   RDF: (暖房, マシュマロ, 使用)
# Item: 暖房, Action: 暖房で手を温める
#   RDF: (暖房, 温める, 行為)
#   RDF: (手, 温める, 行為)
#   RDF: (暖房, 手, 使用)
# Item: 暖房, Action: 暖房で靴下を温める
#   RDF: (暖房, 温める, 行為)
#   RDF: (靴下, 温める, 行為)
#   RDF: (暖房, 靴下, 使用)
# Item: 暖房, Action: 暖房で衣類を乾燥させる
#   RDF: (暖房, 乾燥せる, 行為)
#   RDF: (衣類, 乾燥せる, 行為)
#   RDF: (暖房, 衣類, 使用)
# Item: 暖房, Action: 暖房で小物を温める
#   RDF: (暖房, 温める, 行為)
#   RDF: (小物, 温める, 行為)
#   RDF: (暖房, 小物, 使用)
# Item: 暖房, Action: 暖房で布団を温める
#   RDF: (暖房, 温める, 行為)
#   RDF: (布団, 温める, 行為)
#   RDF: (暖房, 布団, 使用)
# Item: 暖房, Action: 暖房でコーヒーを温める
#   RDF: (暖房, 温める, 行為)
#   RDF: (コーヒー, 温める, 行為)
#   RDF: (暖房, コーヒー, 使用)
# Item: 暖房, Action: 暖房でホットドリンクを作る
#   RDF: (暖房, 作る, 行為)
#   RDF: (ホットドリンク, 作る, 行為)
#   RDF: (暖房, ホットドリンク, 使用)
# Item: 暖房, Action: 暖房でハーブティーを温める
#   RDF: (暖房, 温める, 行為)
#   RDF: (ハーブティー, 温める, 行為)
#   RDF: (暖房, ハーブティー, 使用)
# Item: 暖房, Action: 暖房でスープを温める
#   RDF: (暖房, 温める, 行為)
#   RDF: (スープ, 温める, 行為)
#   RDF: (暖房, スープ, 使用)
# Item: 暖房, Action: 暖房でポップコーンを作る
#   RDF: (暖房, 作る, 行為)
#   RDF: (ポップコーン, 作る, 行為)
#   RDF: (暖房, ポップコーン, 使用)
# Item: 暖房, Action: 暖房でドライフルーツを作る
#   RDF: (暖房, 作る, 行為)
#   RDF: (ドライフルーツ, 作る, 行為)
#   RDF: (暖房, ドライフルーツ, 使用)
# Item: 暖房, Action: 暖房でおもちゃを温める
#   RDF: (暖房, 温める, 行為)
#   RDF: (おもちゃ, 温める, 行為)
#   RDF: (暖房, おもちゃ, 使用)
# Item: 暖房, Action: 暖房でペットのベッドを温める
#   RDF: (暖房, 温める, 行為)
#   RDF: (ベッド, 温める, 行為)
#   RDF: (暖房, ペット, 使用)
#   RDF: (暖房, ベッド, 使用)
#   RDF: (ペット, ベッド, 使用)
# Item: 暖房, Action: 暖房でキャンプ気分を味わう
#   RDF: (暖房, 味わう, 行為)
#   RDF: (気分, 味わう, 行為)
#   RDF: (暖房, キャンプ, 使用)
#   RDF: (暖房, 気分, 使用)
#   RDF: (キャンプ, 気分, 使用)
# Item: 暖房, Action: 暖房で植物を育てる
#   RDF: (暖房, 育てる, 行為)
#   RDF: (植物, 育てる, 行為)
#   RDF: (暖房, 植物, 使用)
# Item: 暖房, Action: 暖房で本を温める
#   RDF: (暖房, 温める, 行為)
#   RDF: (本, 温める, 行為)
#   RDF: (暖房, 本, 使用)
# Item: 暖房, Action: 暖房で雑誌を温める
#   RDF: (暖房, 温める, 行為)
#   RDF: (雑誌, 温める, 行為)
#   RDF: (暖房, 雑誌, 使用)
# Item: 暖房, Action: 暖房でリラックスする
#   RDF: (暖房, リラックスする, 行為)
# Item: 暖房, Action: 暖房でヨガをする
#   RDF: (暖房, する, 行為)
#   RDF: (ヨガ, する, 行為)
#   RDF: (暖房, ヨガ, 使用)
# Item: 暖房, Action: 暖房の電源を入れる
#   RDF: (電源, 入れる, 行為)
#   RDF: (暖房, 電源, 使用)
# Item: 暖房, Action: 暖房の温度を設定する
#   RDF: (温度, 設定する, 行為)
#   RDF: (暖房, 温度, 使用)
# Item: 暖房, Action: 暖房の風量を調整する
#   RDF: (風量, 調整する, 行為)
#   RDF: (暖房, 風量, 使用)
# Item: 暖房, Action: 暖房のタイマーを設定する
#   RDF: (タイマー, 設定する, 行為)
#   RDF: (暖房, タイマー, 使用)
# Item: 暖房, Action: 暖房の運転モードを選ぶ
#   RDF: (モード, 選ぶ, 行為)
#   RDF: (暖房, 運転, 使用)
#   RDF: (暖房, モード, 使用)
#   RDF: (運転, モード, 使用)
# Item: 暖房, Action: 暖房のフィルターを確認する
#   RDF: (フィルター, 確認する, 行為)
#   RDF: (暖房, フィルター, 使用)
# Item: 暖房, Action: 暖房のフィルターを掃除する
#   RDF: (フィルター, 掃除する, 行為)
#   RDF: (暖房, フィルター, 使用)
# Item: 暖房, Action: 暖房の電源を切る
#   RDF: (電源, 切る, 行為)
#   RDF: (暖房, 電源, 使用)
# Item: 暖房, Action: 暖房の位置を調整する
#   RDF: (位置, 調整する, 行為)
#   RDF: (暖房, 位置, 使用)
# Item: 暖房, Action: 暖房のリモコンを使う
#   RDF: (リモコン, 使う, 行為)
#   RDF: (暖房, リモコン, 使用)
# Item: 暖房, Action: 暖房の操作パネルを確認する
#   RDF: (パネル, 確認する, 行為)
#   RDF: (暖房, 操作, 使用)
#   RDF: (暖房, パネル, 使用)
#   RDF: (操作, パネル, 使用)
# Item: 暖房, Action: 暖房の換気を確認する
#   RDF: (換気, 確認する, 行為)
#   RDF: (暖房, 換気, 使用)
# Item: 暖房, Action: 暖房の音を確認する
#   RDF: (音, 確認する, 行為)
#   RDF: (暖房, 音, 使用)
# Item: 暖房, Action: 暖房の使用説明書を読む
#   RDF: (使用説明書, 読む, 行為)
#   RDF: (暖房, 使用説明書, 使用)
# Item: 暖房, Action: 暖房の点検をする
#   RDF: (点検, する, 行為)
#   RDF: (暖房, 点検, 使用)
# Item: 暖房, Action: 暖房の消耗品を交換する
#   RDF: (消耗品, 交換する, 行為)
#   RDF: (暖房, 消耗品, 使用)
# Item: 暖房, Action: 暖房のエアフィルターを交換する
#   RDF: (エアフィルター, 交換する, 行為)
#   RDF: (暖房, エアフィルター, 使用)
# Item: 暖房, Action: 暖房の定期メンテナンスをする
#   RDF: (メンテナンス, する, 行為)
#   RDF: (暖房, 定期, 使用)
#   RDF: (暖房, メンテナンス, 使用)
#   RDF: (定期, メンテナンス, 使用)
# Item: 暖房, Action: 暖房の異常を確認する
#   RDF: (異常, 確認する, 行為)
#   RDF: (暖房, 異常, 使用)
# Item: 暖房, Action: 暖房の安全装置を確認する
#   RDF: (装置, 確認する, 行為)
#   RDF: (暖房, 安全, 使用)
#   RDF: (暖房, 装置, 使用)
#   RDF: (安全, 装置, 使用)
# Item: 暖房, Action: 暖房の電源が入らない
#   RDF: (暖房, 電源, 使用)
# Item: 暖房, Action: 暖房が過熱する
# Item: 暖房, Action: 暖房のフィルターが詰まる
#   RDF: (暖房, フィルター, 使用)
# Item: 暖房, Action: 暖房の風量が弱い
#   RDF: (暖房, 風量, 使用)
# Item: 暖房, Action: 暖房の温度が上がらない
#   RDF: (暖房, 温度, 使用)
# Item: 暖房, Action: 暖房が異音を出す
#   RDF: (異音, 出す, 行為)
#   RDF: (暖房, 異音, 使用)
# Item: 暖房, Action: 暖房のリモコンが動かない
#   RDF: (暖房, リモコン, 使用)
# Item: 暖房, Action: 暖房のタイマーが動かない
#   RDF: (暖房, タイマー, 使用)
# Item: 暖房, Action: 暖房の設定が変わらない
#   RDF: (暖房, 設定, 使用)
# Item: 暖房, Action: 暖房が煙を出す
#   RDF: (煙, 出す, 行為)
#   RDF: (暖房, 煙, 使用)
# Item: 暖房, Action: 暖房の電源が突然切れる
#   RDF: (暖房, 電源, 使用)
# Item: 暖房, Action: 暖房が水漏れする
# Item: 暖房, Action: 暖房が電気を食い過ぎる
#   RDF: (電気, 食う, 行為)
#   RDF: (暖房, 電気, 使用)
# Item: 暖房, Action: 暖房が火災を引き起こす
#   RDF: (火災, 引き起こす, 行為)
#   RDF: (暖房, 火災, 使用)
# Item: 暖房, Action: 暖房のフィルターが汚れる
#   RDF: (暖房, フィルター, 使用)
# Item: 暖房, Action: 暖房が異常に冷たい風を出す
#   RDF: (風, 出す, 行為)
#   RDF: (暖房, 風, 使用)
# Item: 暖房, Action: 暖房が燃料を漏らす
#   RDF: (燃料, 漏らす, 行為)
#   RDF: (暖房, 燃料, 使用)
# Item: 暖房, Action: 暖房の電源コードが短絡する
#   RDF: (暖房, 電源, 使用)
#   RDF: (暖房, コード, 使用)
#   RDF: (電源, コード, 使用)
# Item: 暖房, Action: 暖房が倒れる
# Item: 暖房, Action: 暖房が水蒸気を出す
#   RDF: (水蒸気, 出す, 行為)
#   RDF: (暖房, 水蒸気, 使用)
# Item: 暖房, Action: 暖房の使い方を教える
#   RDF: (使い方, 教える, 行為)
#   RDF: (暖房, 使い方, 使用)
# Item: 暖房, Action: 暖房を一緒に使う
#   RDF: (暖房, 使う, 行為)
#   RDF: (一緒, 使う, 行為)
#   RDF: (暖房, 一緒, 使用)
# Item: 暖房, Action: 暖房の設定を手伝う
#   RDF: (設定, 手伝う, 行為)
#   RDF: (暖房, 設定, 使用)
# Item: 暖房, Action: 暖房の掃除を手伝う
#   RDF: (掃除, 手伝う, 行為)
#   RDF: (暖房, 掃除, 使用)
# Item: 暖房, Action: 暖房のメンテナンスを手伝う
#   RDF: (メンテナンス, 手伝う, 行為)
#   RDF: (暖房, メンテナンス, 使用)
# Item: 暖房, Action: 暖房の購入を相談する
#   RDF: (購入, 相談する, 行為)
#   RDF: (暖房, 購入, 使用)
# Item: 暖房, Action: 暖房の特徴を話す
#   RDF: (特徴, 話す, 行為)
#   RDF: (暖房, 特徴, 使用)
# Item: 暖房, Action: 暖房の魅力を伝える
#   RDF: (魅力, 伝える, 行為)
#   RDF: (暖房, 魅力, 使用)
# Item: 暖房, Action: 暖房の修理を手伝う
#   RDF: (修理, 手伝う, 行為)
#   RDF: (暖房, 修理, 使用)
# Item: 暖房, Action: 暖房の収納を手伝う
#   RDF: (収納, 手伝う, 行為)
#   RDF: (暖房, 収納, 使用)
# Item: 暖房, Action: 暖房の歴史を調べる
#   RDF: (歴史, 調べる, 行為)
#   RDF: (暖房, 歴史, 使用)
# Item: 暖房, Action: 暖房の展示を手伝う
#   RDF: (展示, 手伝う, 行為)
#   RDF: (暖房, 展示, 使用)
# Item: 暖房, Action: 暖房の情報を交換する
#   RDF: (情報, 交換する, 行為)
#   RDF: (暖房, 情報, 使用)
# Item: 暖房, Action: 暖房のブランドを比べる
#   RDF: (ブランド, 比べる, 行為)
#   RDF: (暖房, ブランド, 使用)
# Item: 暖房, Action: 暖房の機能を説明する
#   RDF: (機能, 説明する, 行為)
#   RDF: (暖房, 機能, 使用)
# Item: 暖房, Action: 暖房の使い心地を話す
#   RDF: (使い心地, 話す, 行為)
#   RDF: (暖房, 使い心地, 使用)
# Item: 暖房, Action: 暖房のおすすめを紹介する
#   RDF: (おすすめ, 紹介する, 行為)
#   RDF: (暖房, おすすめ, 使用)
# Item: 暖房, Action: 暖房のフィルターを交換する手伝いをする
#   RDF: (フィルター, 交換する, 行為)
#   RDF: (手伝い, する, 行為)
#   RDF: (暖房, フィルター, 使用)
#   RDF: (暖房, 手伝い, 使用)
#   RDF: (フィルター, 手伝い, 使用)
# Item: 暖房, Action: 暖房の燃料を補充する手伝いをする
#   RDF: (燃料, 補充する, 行為)
#   RDF: (手伝い, する, 行為)
#   RDF: (暖房, 燃料, 使用)
#   RDF: (暖房, 手伝い, 使用)
#   RDF: (燃料, 手伝い, 使用)
# Item: 暖房, Action: 暖房の温度設定を一緒に考える
#   RDF: (設定, 考える, 行為)
#   RDF: (一緒, 考える, 行為)
#   RDF: (暖房, 温度, 使用)
#   RDF: (暖房, 設定, 使用)
#   RDF: (暖房, 一緒, 使用)
#   RDF: (温度, 設定, 使用)
#   RDF: (温度, 一緒, 使用)
#   RDF: (設定, 一緒, 使用)

# %%
import rdflib
from rdflib import Graph, URIRef, Literal
from rdflib.namespace import RDF, Namespace
from pyvis.network import Network
from IPython.display import display, HTML

# Create RDF graph and add triples
g = Graph()

# Define namespaces
ex = Namespace('http://example.org/')

for item, act, rdf_triples in dependencies_list:
    for rdf in rdf_triples:
        subject = URIRef(f"http://example.org/{rdf[0]}")
        predicate = URIRef(f"http://example.org/{rdf[2]}")
        obj = URIRef(f"http://example.org/{rdf[1]}")
        g.add((subject, predicate, obj))

# %%
# Create a pyvis network
net = Network(notebook=True, cdn_resources='remote')

# Add nodes and edges to the network
for s, p, o in g:
    s_str = str(s).replace('http://example.org/', '')
    o_str = str(o).replace('http://example.org/', '')
    p_str = str(p).replace('http://example.org/', '')
    net.add_node(s_str, label=s_str)
    net.add_node(o_str, label=o_str)
    net.add_edge(s_str, o_str, title=p_str)

# Generate the network and save it as an HTML file
net.show('rdf_network.html')

# Display the HTML file in the notebook
display(HTML('rdf_network.html'))
# Out:
# rdf_network.html
# <html>
#     <head>
#         <meta charset="utf-8">
#
#             <script>function neighbourhoodHighlight(params) {
#   // console.log("in nieghbourhoodhighlight");
#   allNodes = nodes.get({ returnType: "Object" });
#   // originalNodes = JSON.parse(JSON.stringify(allNodes));
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     highlightActive = true;
#     var i, j;
#     var selectedNode = params.nodes[0];
#     var degrees = 2;
#
#     // mark all nodes as hard to read.
#     for (let nodeId in allNodes) {
#       // nodeColors[nodeId] = allNodes[nodeId].color;
#       allNodes[nodeId].color = "rgba(200,200,200,0.5)";
#       if (allNodes[nodeId].hiddenLabel === undefined) {
#         allNodes[nodeId].hiddenLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#     var connectedNodes = network.getConnectedNodes(selectedNode);
#     var allConnectedNodes = [];
#
#     // get the second degree nodes
#     for (i = 1; i < degrees; i++) {
#       for (j = 0; j < connectedNodes.length; j++) {
#         allConnectedNodes = allConnectedNodes.concat(
#           network.getConnectedNodes(connectedNodes[j])
#         );
#       }
#     }
#
#     // all second degree nodes get a different color and their label back
#     for (i = 0; i < allConnectedNodes.length; i++) {
#       // allNodes[allConnectedNodes[i]].color = "pink";
#       allNodes[allConnectedNodes[i]].color = "rgba(150,150,150,0.75)";
#       if (allNodes[allConnectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[allConnectedNodes[i]].label =
#           allNodes[allConnectedNodes[i]].hiddenLabel;
#         allNodes[allConnectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // all first degree nodes get their own color and their label back
#     for (i = 0; i < connectedNodes.length; i++) {
#       // allNodes[connectedNodes[i]].color = undefined;
#       allNodes[connectedNodes[i]].color = nodeColors[connectedNodes[i]];
#       if (allNodes[connectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[connectedNodes[i]].label =
#           allNodes[connectedNodes[i]].hiddenLabel;
#         allNodes[connectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // the main node gets its own color and its label back.
#     // allNodes[selectedNode].color = undefined;
#     allNodes[selectedNode].color = nodeColors[selectedNode];
#     if (allNodes[selectedNode].hiddenLabel !== undefined) {
#       allNodes[selectedNode].label = allNodes[selectedNode].hiddenLabel;
#       allNodes[selectedNode].hiddenLabel = undefined;
#     }
#   } else if (highlightActive === true) {
#     // console.log("highlightActive was true");
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       // allNodes[nodeId].color = "purple";
#       allNodes[nodeId].color = nodeColors[nodeId];
#       // delete allNodes[nodeId].color;
#       if (allNodes[nodeId].hiddenLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].hiddenLabel;
#         allNodes[nodeId].hiddenLabel = undefined;
#       }
#     }
#     highlightActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     // console.log("Nothing was selected");
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         // allNodes[nodeId].color = {};
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function filterHighlight(params) {
#   allNodes = nodes.get({ returnType: "Object" });
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     filterActive = true;
#     let selectedNodes = params.nodes;
#
#     // hiding all nodes and saving the label
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = true;
#       if (allNodes[nodeId].savedLabel === undefined) {
#         allNodes[nodeId].savedLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#
#     for (let i=0; i < selectedNodes.length; i++) {
#       allNodes[selectedNodes[i]].hidden = false;
#       if (allNodes[selectedNodes[i]].savedLabel !== undefined) {
#         allNodes[selectedNodes[i]].label = allNodes[selectedNodes[i]].savedLabel;
#         allNodes[selectedNodes[i]].savedLabel = undefined;
#       }
#     }
#
#   } else if (filterActive === true) {
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = false;
#       if (allNodes[nodeId].savedLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].savedLabel;
#         allNodes[nodeId].savedLabel = undefined;
#       }
#     }
#     filterActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function selectNode(nodes) {
#   network.selectNodes(nodes);
#   neighbourhoodHighlight({ nodes: nodes });
#   return nodes;
# }
#
# function selectNodes(nodes) {
#   network.selectNodes(nodes);
#   filterHighlight({nodes: nodes});
#   return nodes;
# }
#
# function highlightFilter(filter) {
#   let selectedNodes = []
#   let selectedProp = filter['property']
#   if (filter['item'] === 'node') {
#     let allNodes = nodes.get({ returnType: "Object" });
#     for (let nodeId in allNodes) {
#       if (allNodes[nodeId][selectedProp] && filter['value'].includes((allNodes[nodeId][selectedProp]).toString())) {
#         selectedNodes.push(nodeId)
#       }
#     }
#   }
#   else if (filter['item'] === 'edge'){
#     let allEdges = edges.get({returnType: 'object'});
#     // check if the selected property exists for selected edge and select the nodes connected to the edge
#     for (let edge in allEdges) {
#       if (allEdges[edge][selectedProp] && filter['value'].includes((allEdges[edge][selectedProp]).toString())) {
#         selectedNodes.push(allEdges[edge]['from'])
#         selectedNodes.push(allEdges[edge]['to'])
#       }
#     }
#   }
#   selectNodes(selectedNodes)
# }</script>
#             <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/dist/vis-network.min.css" integrity="sha512-WgxfT5LWjfszlPHXRmBWHkV2eceiWTOBvrKCNbdgDYTHrT2AeLCGbF4sZlZw3UMN3WtL0tGUoIAKsu8mllg/XA==" crossorigin="anonymous" referrerpolicy="no-referrer" />
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/vis-network.min.js" integrity="sha512-LnvoEWDFrqGHlHmDD2101OrLcbsfkrzoSpvtSQtxK3RMnRV0eOkhhBN2dXHKRrUU8p2DGRTk35n4O8nWSVe1mQ==" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
#
#
#
#
#
#
#
#
# <center>
# <h1></h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#         <link
#           href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/css/bootstrap.min.css"
#           rel="stylesheet"
#           integrity="sha384-eOJMYsd53ii+scO/bJGFsiCZc+5NDVN2yr8+0RDqr0Ql0h+rP48ckxlpbzKgwra6"
#           crossorigin="anonymous"
#         />
#         <script
#           src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/js/bootstrap.bundle.min.js"
#           integrity="sha384-JEW9xMcG8R+pH31jmWH6WWP0WintQrMb4s7ZOdauHnUtxwoG2vI5DkLtS3qm9Ekf"
#           crossorigin="anonymous"
#         ></script>
#
#
#         <center>
#           <h1></h1>
#         </center>
#         <style type="text/css">
#
#              #mynetwork {
#                  width: 100%;
#                  height: 600px;
#                  backgr
